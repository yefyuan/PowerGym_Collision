# %% [markdown]
# # Tutorial 4: CTDE Training
#
# **Goal:** Train coordinator-level policies using Centralized Training with Decentralized Execution (CTDE).
#
# **Time:** ~10 minutes
#
# ---
#
# ## CTDE in HERON
#
# HERON's hierarchical architecture naturally supports CTDE:
#
# ```
# Training (Centralized)              Execution (Decentralized)
#
# SystemAgent                         SystemAgent
#   |                                   |
#   +-- Coordinator (policy)            +-- Coordinator (policy)
#   |     +-- Device 1                  |     +-- Device 1
#   |     +-- Device 2                  |     +-- Device 2
#   |                                   |
#   +-- Coordinator (policy)            +-- Coordinator (policy)
#         +-- Device 3                        +-- Device 3
#
# env.step(actions)                   env.run_event_driven()
# All agents step together            Agents tick independently
# Shared reward signal                Local observations only
# ```
#
# **Key Pattern:**
# - Coordinators own policies and compute joint actions
# - `VerticalProtocol` decomposes joint actions into per-device actions
# - Devices apply individual actions and report rewards

# %% [markdown]
# ## Step 1: Build Agent Hierarchy
#
# We use the production `PowerGridAgent`, `Generator`, and `ESS` classes with `VerticalProtocol` for action distribution.

# %%
import os
import warnings
warnings.filterwarnings('ignore')

import numpy as np
from typing import Any, Dict, List, Optional
from dataclasses import dataclass, field

# HERON imports
from heron.agents.system_agent import SystemAgent
from heron.core.observation import Observation
from heron.core.action import Action
from heron.core.policies import Policy, obs_to_vector, vector_to_action
from heron.protocols.vertical import VerticalProtocol
from heron.scheduling import ScheduleConfig, JitterType
from heron.scheduling.analysis import EpisodeAnalyzer

# PowerGrid imports
from powergrid.agents import PowerGridAgent, Generator, ESS
from powergrid.envs import HierarchicalMicrogridEnv

print("Imports ready!")
# Out:
# Imports ready!

# %%
def create_microgrid(mg_id: str, num_gen: int = 1, num_ess: int = 1) -> PowerGridAgent:
    """Create a microgrid coordinator with generators and ESS devices."""
    subordinates = {}

    for i in range(num_gen):
        gen_id = f"{mg_id}_Gen{i + 1}"
        subordinates[gen_id] = Generator(
            agent_id=gen_id,
            bus=f"{mg_id}_bus",
            p_min_MW=0.1,
            p_max_MW=1.0 + 0.5 * i,
            cost_curve_coefs=(0.01 + 0.005 * i, 0.4 + 0.1 * i, 0.0),
        )

    for i in range(num_ess):
        ess_id = f"{mg_id}_ESS{i + 1}"
        subordinates[ess_id] = ESS(
            agent_id=ess_id,
            bus=f"{mg_id}_bus",
            capacity_MWh=2.0 + i,
            p_min_MW=-0.5 - 0.1 * i,
            p_max_MW=0.5 + 0.1 * i,
            degr_cost_per_MWh=0.1,
        )

    # VerticalProtocol decomposes coordinator's joint action into per-device actions
    return PowerGridAgent(
        agent_id=mg_id,
        subordinates=subordinates,
        protocol=VerticalProtocol(),
    )


# Build 3-microgrid hierarchy
mg1 = create_microgrid("MG1", num_gen=1, num_ess=1)
mg2 = create_microgrid("MG2", num_gen=2, num_ess=1)
mg3 = create_microgrid("MG3", num_gen=1, num_ess=2)

system_agent = SystemAgent(
    agent_id="system_agent",
    subordinates={"MG1": mg1, "MG2": mg2, "MG3": mg3},
)

print("=== Agent Hierarchy ===")
print(f"L3 SystemAgent: {system_agent.agent_id}")
for mg_id, mg in system_agent.subordinates.items():
    devices = list(mg.subordinates.keys())
    print(f"  L2 {mg_id}: {devices} (protocol={type(mg.protocol).__name__})")
# Out:
# === Agent Hierarchy ===
# L3 SystemAgent: system_agent
#   L2 MG1: ['MG1_Gen1', 'MG1_ESS1'] (protocol=VerticalProtocol)
#   L2 MG2: ['MG2_Gen1', 'MG2_Gen2', 'MG2_ESS1'] (protocol=VerticalProtocol)
#   L2 MG3: ['MG3_Gen1', 'MG3_ESS1', 'MG3_ESS2'] (protocol=VerticalProtocol)

# %% [markdown]
# ## Step 2: Create Environment
#
# `HierarchicalMicrogridEnv` connects the agent hierarchy to PandaPower simulation.

# %%
# Dataset path (relative to this notebook)
dataset_path = os.path.abspath(os.path.join(
    os.path.dirname('__file__'), '..', 'powergrid', 'data.pkl'
))

env = HierarchicalMicrogridEnv(
    system_agent=system_agent,
    dataset_path=dataset_path,
    episode_steps=24,
    dt=1.0,
)

print(f"Registered agents ({len(env.registered_agents)}):")
for aid in sorted(env.registered_agents.keys()):
    agent = env.registered_agents[aid]
    print(f"  {aid}: {type(agent).__name__}")
# Out:
# Registered agents (13):
#   MG1: PowerGridAgent
#   MG1_ESS1: ESS
#   MG1_Gen1: Generator
#   MG2: PowerGridAgent
#   MG2_ESS1: ESS
#   MG2_Gen1: Generator
#   MG2_Gen2: Generator
#   MG3: PowerGridAgent
#   MG3_ESS1: ESS
#   MG3_ESS2: ESS
#   MG3_Gen1: Generator
#   proxy_agent: Proxy
#   system_agent: SystemAgent

# %% [markdown]
# ## Step 3: Define Coordinator Policy
#
# Each coordinator gets an actor-critic neural network.
# The policy uses HERON's `Policy` base class with `@obs_to_vector` and `@vector_to_action` decorators
# for automatic observation extraction and action conversion.

# %%
class SimpleMLP:
    """Simple MLP for value function approximation."""

    def __init__(self, input_dim: int, hidden_dim: int, output_dim: int, seed: int = 42):
        np.random.seed(seed)
        self.W1 = np.random.randn(input_dim, hidden_dim) * np.sqrt(2.0 / input_dim)
        self.b1 = np.zeros(hidden_dim)
        self.W2 = np.random.randn(hidden_dim, output_dim) * np.sqrt(2.0 / hidden_dim)
        self.b2 = np.zeros(output_dim)

    def forward(self, x: np.ndarray) -> np.ndarray:
        h = np.maximum(0, x @ self.W1 + self.b1)  # ReLU
        return np.tanh(h @ self.W2 + self.b2)

    def update(self, x: np.ndarray, target: np.ndarray, lr: float = 0.01) -> None:
        h = np.maximum(0, x @ self.W1 + self.b1)
        out = np.tanh(h @ self.W2 + self.b2)
        d_out = (out - target) * (1 - out**2)
        self.W2 -= lr * np.outer(h, d_out)
        self.b2 -= lr * d_out
        d_h = d_out @ self.W2.T
        d_h[h <= 0] = 0
        self.W1 -= lr * np.outer(x, d_h)
        self.b1 -= lr * d_h


class ActorMLP(SimpleMLP):
    """Actor network with policy gradient updates."""

    def __init__(self, input_dim: int, hidden_dim: int, output_dim: int, seed: int = 42):
        super().__init__(input_dim, hidden_dim, output_dim, seed)
        self.W2 = np.random.randn(hidden_dim, output_dim) * 0.1
        self.b2 = np.zeros(output_dim)

    def update(self, x: np.ndarray, action_taken: np.ndarray, advantage: float, lr: float = 0.01) -> None:
        h = np.maximum(0, x @ self.W1 + self.b1)
        current_action = np.tanh(h @ self.W2 + self.b2)
        error = current_action - action_taken
        grad_scale = advantage * (1 - current_action**2)
        d_W2 = np.outer(h, grad_scale * error)
        d_b2 = grad_scale * error
        d_h = (grad_scale * error) @ self.W2.T
        d_h[h <= 0] = 0
        self.W2 -= lr * d_W2
        self.b2 -= lr * d_b2.flatten()
        self.W1 -= lr * np.outer(x, d_h)
        self.b1 -= lr * d_h.flatten()


class CoordinatorNeuralPolicy(Policy):
    """Neural policy for coordinator (microgrid) that computes joint action.
    
    Uses HERON's Policy interface with decorators:
    - @obs_to_vector: Converts Observation -> numpy array
    - @vector_to_action: Converts numpy array -> Action object
    """

    def __init__(self, obs_dim: int, action_dim: int, hidden_dim: int = 32, seed: int = 42):
        self.obs_dim = obs_dim
        self.action_dim = action_dim
        self.action_range = (-1.0, 1.0)
        self.actor = ActorMLP(obs_dim, hidden_dim, action_dim, seed)
        self.critic = SimpleMLP(obs_dim, hidden_dim, 1, seed + 1)
        self.noise_scale = 0.15

    def _normalize_obs(self, obs_vec: np.ndarray) -> np.ndarray:
        if len(obs_vec) > self.obs_dim:
            return obs_vec[:self.obs_dim]
        elif len(obs_vec) < self.obs_dim:
            return np.pad(obs_vec, (0, self.obs_dim - len(obs_vec)))
        return obs_vec

    @obs_to_vector
    @vector_to_action
    def forward(self, obs_vec: np.ndarray) -> np.ndarray:
        obs_vec = self._normalize_obs(obs_vec)
        action_mean = self.actor.forward(obs_vec)
        action_vec = action_mean + np.random.normal(0, self.noise_scale, self.action_dim)
        return np.clip(action_vec, -1.0, 1.0)

    @obs_to_vector
    def get_value(self, obs_vec: np.ndarray) -> float:
        obs_vec = self._normalize_obs(obs_vec)
        return float(self.critic.forward(obs_vec)[0])

    def update(self, obs: np.ndarray, action_taken: np.ndarray, advantage: float, lr: float = 0.01):
        self.actor.update(obs, action_taken, advantage, lr)

    def update_critic(self, obs: np.ndarray, target: float, lr: float = 0.01):
        self.critic.update(obs, np.array([target]), lr)

    def decay_noise(self, decay_rate: float = 0.995, min_noise: float = 0.05):
        self.noise_scale = max(min_noise, self.noise_scale * decay_rate)


print("Policy classes defined!")
# Out:
# Policy classes defined!

# %% [markdown]
# ## Step 4: CTDE Training Loop
#
# The training loop follows this flow each step:
#
# ```
# 1. Coordinator aggregates subordinate observations
# 2. Coordinator policy computes joint action
# 3. VerticalProtocol decomposes into per-device actions
# 4. env.step(device_actions) runs simulation
# 5. Device rewards are aggregated back to coordinator
# 6. Policy gradient update with advantage estimation
# ```

# %%
# Identify coordinators and their devices
coordinator_ids = []
coordinator_device_ids: Dict[str, List[str]] = {}

for aid, agent in env.registered_agents.items():
    if isinstance(agent, PowerGridAgent) and agent.subordinates:
        coordinator_ids.append(aid)
        coordinator_device_ids[aid] = list(agent.subordinates.keys())

# Reset to get initial observations and compute obs dimensions
obs, _ = env.reset(seed=0)

obs_dims_per_device: Dict[str, int] = {}
obs_dims_per_coordinator: Dict[str, int] = {}

for coord_id in coordinator_ids:
    total_dim = 0
    for sub_id in coordinator_device_ids[coord_id]:
        if sub_id in obs:
            sub_obs = obs[sub_id]
            dim = sub_obs.local_vector().shape[0] if isinstance(sub_obs, Observation) else len(np.asarray(sub_obs).flatten())
            dim = max(dim, 2)
            obs_dims_per_device[sub_id] = dim
            total_dim += dim
    obs_dims_per_coordinator[coord_id] = max(total_dim, 4)

# Create policies
coordinator_policies: Dict[str, CoordinatorNeuralPolicy] = {}

print("Coordinator policies:")
for i, coord_id in enumerate(coordinator_ids):
    obs_dim = obs_dims_per_coordinator[coord_id]
    action_dim = len(coordinator_device_ids[coord_id])
    coordinator_policies[coord_id] = CoordinatorNeuralPolicy(
        obs_dim=obs_dim, action_dim=action_dim, hidden_dim=32, seed=42 + i,
    )
    print(f"  {coord_id}: obs_dim={obs_dim}, action_dim={action_dim}, devices={coordinator_device_ids[coord_id]}")
# Out:
# Coordinator policies:
#   MG1: obs_dim=7, action_dim=2, devices=['MG1_Gen1', 'MG1_ESS1']
#   MG2: obs_dim=9, action_dim=3, devices=['MG2_Gen1', 'MG2_Gen2', 'MG2_ESS1']
#   MG3: obs_dim=12, action_dim=3, devices=['MG3_Gen1', 'MG3_ESS1', 'MG3_ESS2']

# %%
# CTDE Training
num_episodes = 30
steps_per_episode = 24
gamma = 0.99
lr = 0.02

returns_history = []
mg_rewards_history = {cid: [] for cid in coordinator_ids}

print(f"Training {num_episodes} episodes x {steps_per_episode} steps...")
print(f"{'='*60}")
print(f"{'Ep':>4} | {'Return':>10} | {'MA(5)':>10} | {'MG1':>8} | {'MG2':>8} | {'MG3':>8}")
print(f"{'-'*60}")

for episode in range(num_episodes):
    obs, _ = env.reset(seed=episode)
    trajectories = {
        cid: {"obs": [], "actions": [], "rewards": []}
        for cid in coordinator_ids
    }
    episode_return = 0.0
    mg_episode_rewards = {cid: 0.0 for cid in coordinator_ids}

    for step in range(steps_per_episode):
        all_device_actions = {}

        for coord_id in coordinator_ids:
            sub_ids = coordinator_device_ids[coord_id]
            policy = coordinator_policies[coord_id]

            # 1. Aggregate subordinate observations into coordinator obs
            aggregated_obs = []
            for sub_id in sub_ids:
                sub_dim = obs_dims_per_device.get(sub_id, 4)
                obs_value = obs.get(sub_id)
                if obs_value is None:
                    aggregated_obs.append(np.zeros(sub_dim, dtype=np.float32))
                    continue
                obs_vec = obs_value.local_vector() if isinstance(obs_value, Observation) else np.asarray(obs_value, dtype=np.float32).flatten()
                if len(obs_vec) > sub_dim:
                    obs_vec = obs_vec[:sub_dim]
                elif len(obs_vec) < sub_dim:
                    obs_vec = np.pad(obs_vec, (0, sub_dim - len(obs_vec)))
                aggregated_obs.append(obs_vec)

            agg_vec = np.concatenate(aggregated_obs) if aggregated_obs else np.zeros(4)
            coord_observation = Observation(timestamp=step, local={"obs": agg_vec})

            # 2. Coordinator policy computes joint action
            coord_action = policy.forward(coord_observation)

            trajectories[coord_id]["obs"].append(agg_vec.copy())
            trajectories[coord_id]["actions"].append(coord_action.c.copy())

            # 3. VerticalProtocol decomposes into per-device actions
            coord_agent = env.registered_agents.get(coord_id)
            if coord_agent and coord_agent.protocol:
                _, distributed_actions = coord_agent.protocol.coordinate(
                    coordinator_state=coord_agent.state,
                    coordinator_action=coord_action,
                    info_for_subordinates={sid: obs.get(sid) for sid in sub_ids},
                )
                for sub_id, sub_action in distributed_actions.items():
                    if sub_action is not None:
                        action_obj = Action()
                        action_obj.set_specs(dim_c=1, range=(np.array([-1.0]), np.array([1.0])))
                        if isinstance(sub_action, np.ndarray):
                            action_obj.set_values(c=sub_action.flatten()[:1])
                        else:
                            action_obj.set_values(c=np.array([float(sub_action)]))
                        all_device_actions[sub_id] = action_obj

        # 4. Step environment with device actions
        obs, rewards, terminated, _, info = env.step(all_device_actions)

        # 5. Aggregate device rewards to coordinators
        for coord_id in coordinator_ids:
            coord_reward = sum(rewards.get(sid, 0.0) for sid in coordinator_device_ids[coord_id])
            trajectories[coord_id]["rewards"].append(coord_reward)
            episode_return += coord_reward
            mg_episode_rewards[coord_id] += coord_reward

        if terminated.get("__all__", False):
            break

    # 6. Policy gradient update with advantage estimation
    for coord_id, traj in trajectories.items():
        if not traj["rewards"]:
            continue
        policy = coordinator_policies[coord_id]

        # Compute discounted returns
        returns = []
        G = 0
        for r in reversed(traj["rewards"]):
            G = r + gamma * G
            returns.insert(0, G)
        returns = np.array(returns)

        # Update actor and critic
        for t in range(len(traj["obs"])):
            obs_t = traj["obs"][t]
            baseline = policy.get_value(Observation(timestamp=t, local={"obs": obs_t}))
            advantage = returns[t] - baseline
            policy.update(obs_t, traj["actions"][t], advantage, lr=lr)
            policy.update_critic(obs_t, returns[t], lr=lr)

        policy.decay_noise()

    # Track progress
    returns_history.append(episode_return)
    for cid in coordinator_ids:
        mg_rewards_history[cid].append(mg_episode_rewards[cid])

    # Print progress every 5 episodes
    if (episode + 1) % 5 == 0:
        ma = np.mean(returns_history[-5:])
        mg_str = " | ".join(f"{mg_episode_rewards[cid]:8.2f}" for cid in coordinator_ids)
        print(f"{episode+1:4d} | {episode_return:10.2f} | {ma:10.2f} | {mg_str}")

print(f"{'='*60}")
print(f"Training complete!")
print(f"  Initial return (first 5): {np.mean(returns_history[:5]):.2f}")
print(f"  Final return (last 5):    {np.mean(returns_history[-5:]):.2f}")
# Out:
# Training 30 episodes x 24 steps...
# ============================================================
#   Ep |     Return |      MA(5) |      MG1 |      MG2 |      MG3
# ------------------------------------------------------------
# [VectorDecomposition] [0.3327 0.1524] -> [('MG1_Gen1', '[0.3327]'), ('MG1_ESS1', '[0.1524]')]
# [VectorDecomposition] [0.1791 0.2436 0.1577] -> [('MG2_Gen1', '[0.1791]'), ('MG2_Gen2', '[0.2436]'), ('MG2_ESS1', '[0.1577]')]
# [VectorDecomposition] [ 0.0221  0.0988 -0.3052] -> [('MG3_Gen1', '[0.0221]'), ('MG3_ESS1', '[0.0988]'), ('MG3_ESS2', '[-0.3052]')]
# [VectorDecomposition] [0.0638 0.2644] -> [('MG1_Gen1', '[0.0638]'), ('MG1_ESS1', '[0.2644]')]
# [VectorDecomposition] [0.2324 0.3081 0.0488] -> [('MG2_Gen1', '[0.2324]'), ('MG2_Gen2', '[0.3081]'), ('MG2_ESS1', '[0.0488]')]
# [VectorDecomposition] [ 0.1895  0.0366 -0.2041] -> [('MG3_Gen1', '[0.1895]'), ('MG3_ESS1', '[0.0366]'), ('MG3_ESS2', '[-0.2041]')]
# [VectorDecomposition] [0.3054 0.2381] -> [('MG1_Gen1', '[0.3054]'), ('MG1_ESS1', '[0.2381]')]
# [VectorDecomposition] [ 0.2676 -0.0255 -0.4475] -> [('MG2_Gen1', '[0.2676]'), ('MG2_Gen2', '[-0.0255]'), ('MG2_ESS1', '[-0.4475]')]
# [VectorDecomposition] [ 0.2678  0.1117 -0.3662] -> [('MG3_Gen1', '[0.2678]'), ('MG3_ESS1', '[0.1117]'), ('MG3_ESS2', '[-0.3662]')]
# [VectorDecomposition] [0.4206 0.1159] -> [('MG1_Gen1', '[0.4206]'), ('MG1_ESS1', '[0.1159]')]
# [VectorDecomposition] [0.2582 0.0652 0.1463] -> [('MG2_Gen1', '[0.2582]'), ('MG2_Gen2', '[0.0652]'), ('MG2_ESS1', '[0.1463]')]
# [VectorDecomposition] [ 0.3901  0.0379 -0.1871] -> [('MG3_Gen1', '[0.3901]'), ('MG3_ESS1', '[0.0379]'), ('MG3_ESS2', '[-0.1871]')]
# [VectorDecomposition] [-0.0521  0.0683] -> [('MG1_Gen1', '[-0.0521]'), ('MG1_ESS1', '[0.0683]')]
# [VectorDecomposition] [0.2147 0.1255 0.0863] -> [('MG2_Gen1', '[0.2147]'), ('MG2_Gen2', '[0.1255]'), ('MG2_ESS1', '[0.0863]')]
# [VectorDecomposition] [ 0.3557 -0.0264 -0.2805] -> [('MG3_Gen1', '[0.3557]'), ('MG3_ESS1', '[-0.0264]'), ('MG3_ESS2', '[-0.2805]')]
# [VectorDecomposition] [-0.0564  0.1613] -> [('MG1_Gen1', '[-0.0564]'), ('MG1_ESS1', '[0.1613]')]
# [VectorDecomposition] [ 0.0213  0.3996 -0.1842] -> [('MG2_Gen1', '[0.0213]'), ('MG2_Gen2', '[0.3996]'), ('MG2_ESS1', '[-0.1842]')]
# [VectorDecomposition] [ 0.1267 -0.1273 -0.1109] -> [('MG3_Gen1', '[0.1267]'), ('MG3_ESS1', '[-0.1273]'), ('MG3_ESS2', '[-0.1109]')]
# [VectorDecomposition] [-0.1274  0.381 ] -> [('MG1_Gen1', '[-0.1274]'), ('MG1_ESS1', '[0.381]')]
# [VectorDecomposition] [ 0.1627  0.1645 -0.1881] -> [('MG2_Gen1', '[0.1627]'), ('MG2_Gen2', '[0.1645]'), ('MG2_ESS1', '[-0.1881]')]
# [VectorDecomposition] [ 0.058   0.0715 -0.1786] -> [('MG3_Gen1', '[0.058]'), ('MG3_ESS1', '[0.0715]'), ('MG3_ESS2', '[-0.1786]')]
# [VectorDecomposition] [0.1542 0.53  ] -> [('MG1_Gen1', '[0.1542]'), ('MG1_ESS1', '[0.53]')]
# [VectorDecomposition] [ 0.2301  0.0444 -0.2293] -> [('MG2_Gen1', '[0.2301]'), ('MG2_Gen2', '[0.0444]'), ('MG2_ESS1', '[-0.2293]')]
# [VectorDecomposition] [ 0.2059 -0.0362 -0.5088] -> [('MG3_Gen1', '[0.2059]'), ('MG3_ESS1', '[-0.0362]'), ('MG3_ESS2', '[-0.5088]')]
# [VectorDecomposition] [0.1842 0.484 ] -> [('MG1_Gen1', '[0.1842]'), ('MG1_ESS1', '[0.484]')]
# [VectorDecomposition] [ 0.119   0.1577 -0.2576] -> [('MG2_Gen1', '[0.119]'), ('MG2_Gen2', '[0.1577]'), ('MG2_ESS1', '[-0.2576]')]
# [VectorDecomposition] [ 0.2859  0.2201 -0.2173] -> [('MG3_Gen1', '[0.2859]'), ('MG3_ESS1', '[0.2201]'), ('MG3_ESS2', '[-0.2173]')]
# [VectorDecomposition] [0.3387 0.3827] -> [('MG1_Gen1', '[0.3387]'), ('MG1_ESS1', '[0.3827]')]
# [VectorDecomposition] [ 0.4522 -0.0151 -0.2475] -> [('MG2_Gen1', '[0.4522]'), ('MG2_Gen2', '[-0.0151]'), ('MG2_ESS1', '[-0.2475]')]
# [VectorDecomposition] [ 0.2416  0.0486 -0.2497] -> [('MG3_Gen1', '[0.2416]'), ('MG3_ESS1', '[0.0486]'), ('MG3_ESS2', '[-0.2497]')]
# [VectorDecomposition] [-0.0085  0.7138] -> [('MG1_Gen1', '[-0.0085]'), ('MG1_ESS1', '[0.7138]')]
# [VectorDecomposition] [ 0.4985 -0.1489  0.1135] -> [('MG2_Gen1', '[0.4985]'), ('MG2_Gen2', '[-0.1489]'), ('MG2_ESS1', '[0.1135]')]
# [VectorDecomposition] [ 0.628   0.2786 -0.2921] -> [('MG3_Gen1', '[0.628]'), ('MG3_ESS1', '[0.2786]'), ('MG3_ESS2', '[-0.2921]')]
# [VectorDecomposition] [0.0253 0.743 ] -> [('MG1_Gen1', '[0.0253]'), ('MG1_ESS1', '[0.743]')]
# [VectorDecomposition] [ 0.3859  0.2692 -0.0881] -> [('MG2_Gen1', '[0.3859]'), ('MG2_Gen2', '[0.2692]'), ('MG2_ESS1', '[-0.0881]')]
# [VectorDecomposition] [ 0.5565  0.1211 -0.1845] -> [('MG3_Gen1', '[0.5565]'), ('MG3_ESS1', '[0.1211]'), ('MG3_ESS2', '[-0.1845]')]
# [VectorDecomposition] [0.1878 0.8563] -> [('MG1_Gen1', '[0.1878]'), ('MG1_ESS1', '[0.8563]')]
# [VectorDecomposition] [0.4699 0.1498 0.1631] -> [('MG2_Gen1', '[0.4699]'), ('MG2_Gen2', '[0.1498]'), ('MG2_ESS1', '[0.1631]')]
# [VectorDecomposition] [ 0.2334 -0.1214 -0.1676] -> [('MG3_Gen1', '[0.2334]'), ('MG3_ESS1', '[-0.1214]'), ('MG3_ESS2', '[-0.1676]')]
# [VectorDecomposition] [0.0038 0.8828] -> [('MG1_Gen1', '[0.0038]'), ('MG1_ESS1', '[0.8828]')]
# [VectorDecomposition] [ 0.417  -0.0173  0.1587] -> [('MG2_Gen1', '[0.417]'), ('MG2_Gen2', '[-0.0173]'), ('MG2_ESS1', '[0.1587]')]
# [VectorDecomposition] [ 0.6832  0.3526 -0.2048] -> [('MG3_Gen1', '[0.6832]'), ('MG3_ESS1', '[0.3526]'), ('MG3_ESS2', '[-0.2048]')]
# [VectorDecomposition] [0.0585 0.8757] -> [('MG1_Gen1', '[0.0585]'), ('MG1_ESS1', '[0.8757]')]
# [VectorDecomposition] [ 0.4584  0.2212 -0.0005] -> [('MG2_Gen1', '[0.4584]'), ('MG2_Gen2', '[0.2212]'), ('MG2_ESS1', '[-0.0005]')]
# [VectorDecomposition] [ 0.4908  0.1507 -0.2553] -> [('MG3_Gen1', '[0.4908]'), ('MG3_ESS1', '[0.1507]'), ('MG3_ESS2', '[-0.2553]')]
# [VectorDecomposition] [0.2418 0.425 ] -> [('MG1_Gen1', '[0.2418]'), ('MG1_ESS1', '[0.425]')]
# [VectorDecomposition] [ 0.5453  0.3016 -0.2479] -> [('MG2_Gen1', '[0.5453]'), ('MG2_Gen2', '[0.3016]'), ('MG2_ESS1', '[-0.2479]')]
# [VectorDecomposition] [ 0.5087 -0.0018 -0.1402] -> [('MG3_Gen1', '[0.5087]'), ('MG3_ESS1', '[-0.0018]'), ('MG3_ESS2', '[-0.1402]')]
# [VectorDecomposition] [0.2784 0.6532] -> [('MG1_Gen1', '[0.2784]'), ('MG1_ESS1', '[0.6532]')]
# [VectorDecomposition] [ 0.4152  0.1861 -0.2416] -> [('MG2_Gen1', '[0.4152]'), ('MG2_Gen2', '[0.1861]'), ('MG2_ESS1', '[-0.2416]')]
# [VectorDecomposition] [ 0.5367 -0.0298 -0.3163] -> [('MG3_Gen1', '[0.5367]'), ('MG3_ESS1', '[-0.0298]'), ('MG3_ESS2', '[-0.3163]')]
# [VectorDecomposition] [0.2624 0.5613] -> [('MG1_Gen1', '[0.2624]'), ('MG1_ESS1', '[0.5613]')]
# [VectorDecomposition] [ 0.6013 -0.0582 -0.3644] -> [('MG2_Gen1', '[0.6013]'), ('MG2_Gen2', '[-0.0582]'), ('MG2_ESS1', '[-0.3644]')]
# [VectorDecomposition] [ 0.6019  0.0904 -0.327 ] -> [('MG3_Gen1', '[0.6019]'), ('MG3_ESS1', '[0.0904]'), ('MG3_ESS2', '[-0.327]')]
# [VectorDecomposition] [0.5341 0.734 ] -> [('MG1_Gen1', '[0.5341]'), ('MG1_ESS1', '[0.734]')]
# [VectorDecomposition] [ 0.4296  0.2899 -0.3314] -> [('MG2_Gen1', '[0.4296]'), ('MG2_Gen2', '[0.2899]'), ('MG2_ESS1', '[-0.3314]')]
# [VectorDecomposition] [ 0.4742  0.0534 -0.1733] -> [('MG3_Gen1', '[0.4742]'), ('MG3_ESS1', '[0.0534]'), ('MG3_ESS2', '[-0.1733]')]
# [VectorDecomposition] [0.0541 0.4705] -> [('MG1_Gen1', '[0.0541]'), ('MG1_ESS1', '[0.4705]')]
# [VectorDecomposition] [0.5585 0.0169 0.0334] -> [('MG2_Gen1', '[0.5585]'), ('MG2_Gen2', '[0.0169]'), ('MG2_ESS1', '[0.0334]')]
# [VectorDecomposition] [ 0.3865 -0.1074 -0.504 ] -> [('MG3_Gen1', '[0.3865]'), ('MG3_ESS1', '[-0.1074]'), ('MG3_ESS2', '[-0.504]')]
# [VectorDecomposition] [0.1109 0.8793] -> [('MG1_Gen1', '[0.1109]'), ('MG1_ESS1', '[0.8793]')]
# [VectorDecomposition] [ 0.7223  0.1409 -0.3179] -> [('MG2_Gen1', '[0.7223]'), ('MG2_Gen2', '[0.1409]'), ('MG2_ESS1', '[-0.3179]')]
# [VectorDecomposition] [ 0.6888 -0.0863 -0.6924] -> [('MG3_Gen1', '[0.6888]'), ('MG3_ESS1', '[-0.0863]'), ('MG3_ESS2', '[-0.6924]')]
# [VectorDecomposition] [0.3614 0.6381] -> [('MG1_Gen1', '[0.3614]'), ('MG1_ESS1', '[0.6381]')]
# [VectorDecomposition] [ 0.7323  0.1757 -0.006 ] -> [('MG2_Gen1', '[0.7323]'), ('MG2_Gen2', '[0.1757]'), ('MG2_ESS1', '[-0.006]')]
# [VectorDecomposition] [ 0.4732 -0.0937 -0.3691] -> [('MG3_Gen1', '[0.4732]'), ('MG3_ESS1', '[-0.0937]'), ('MG3_ESS2', '[-0.3691]')]
# [VectorDecomposition] [0.0519 0.4901] -> [('MG1_Gen1', '[0.0519]'), ('MG1_ESS1', '[0.4901]')]
# [VectorDecomposition] [ 0.5261  0.129  -0.1883] -> [('MG2_Gen1', '[0.5261]'), ('MG2_Gen2', '[0.129]'), ('MG2_ESS1', '[-0.1883]')]
# [VectorDecomposition] [ 0.3773 -0.0312 -0.8271] -> [('MG3_Gen1', '[0.3773]'), ('MG3_ESS1', '[-0.0312]'), ('MG3_ESS2', '[-0.8271]')]
# [VectorDecomposition] [0.2795 0.3495] -> [('MG1_Gen1', '[0.2795]'), ('MG1_ESS1', '[0.3495]')]
# [VectorDecomposition] [ 0.425   0.1388 -0.2431] -> [('MG2_Gen1', '[0.425]'), ('MG2_Gen2', '[0.1388]'), ('MG2_ESS1', '[-0.2431]')]
# [VectorDecomposition] [ 0.8201 -0.1231 -0.4614] -> [('MG3_Gen1', '[0.8201]'), ('MG3_ESS1', '[-0.1231]'), ('MG3_ESS2', '[-0.4614]')]
# [VectorDecomposition] [0.4369 0.1578] -> [('MG1_Gen1', '[0.4369]'), ('MG1_ESS1', '[0.1578]')]
# [VectorDecomposition] [-0.7917 -0.9051 -0.5455] -> [('MG2_Gen1', '[-0.7917]'), ('MG2_Gen2', '[-0.9051]'), ('MG2_ESS1', '[-0.5455]')]
# [VectorDecomposition] [-0.2392  0.2311 -0.2061] -> [('MG3_Gen1', '[-0.2392]'), ('MG3_ESS1', '[0.2311]'), ('MG3_ESS2', '[-0.2061]')]
# [VectorDecomposition] [0.2178 0.2571] -> [('MG1_Gen1', '[0.2178]'), ('MG1_ESS1', '[0.2571]')]
# [VectorDecomposition] [-0.5753 -1.     -0.7995] -> [('MG2_Gen1', '[-0.5753]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.7995]')]
# [VectorDecomposition] [ 0.087   0.1031 -0.2614] -> [('MG3_Gen1', '[0.087]'), ('MG3_ESS1', '[0.1031]'), ('MG3_ESS2', '[-0.2614]')]
# [VectorDecomposition] [0.146  0.1557] -> [('MG1_Gen1', '[0.146]'), ('MG1_ESS1', '[0.1557]')]
# [VectorDecomposition] [-0.7841 -0.7214 -0.9143] -> [('MG2_Gen1', '[-0.7841]'), ('MG2_Gen2', '[-0.7214]'), ('MG2_ESS1', '[-0.9143]')]
# [VectorDecomposition] [ 0.3332  0.0581 -0.0281] -> [('MG3_Gen1', '[0.3332]'), ('MG3_ESS1', '[0.0581]'), ('MG3_ESS2', '[-0.0281]')]
# [VectorDecomposition] [0.3068 0.1822] -> [('MG1_Gen1', '[0.3068]'), ('MG1_ESS1', '[0.1822]')]
# [VectorDecomposition] [-0.8426 -0.9633 -0.8172] -> [('MG2_Gen1', '[-0.8426]'), ('MG2_Gen2', '[-0.9633]'), ('MG2_ESS1', '[-0.8172]')]
# [VectorDecomposition] [ 0.25   -0.1819 -0.1677] -> [('MG3_Gen1', '[0.25]'), ('MG3_ESS1', '[-0.1819]'), ('MG3_ESS2', '[-0.1677]')]
# [VectorDecomposition] [0.0685 0.1637] -> [('MG1_Gen1', '[0.0685]'), ('MG1_ESS1', '[0.1637]')]
# [VectorDecomposition] [-0.8797 -0.7914 -0.9001] -> [('MG2_Gen1', '[-0.8797]'), ('MG2_Gen2', '[-0.7914]'), ('MG2_ESS1', '[-0.9001]')]
# [VectorDecomposition] [ 0.2498  0.1679 -0.0158] -> [('MG3_Gen1', '[0.2498]'), ('MG3_ESS1', '[0.1679]'), ('MG3_ESS2', '[-0.0158]')]
# [VectorDecomposition] [0.1445 0.1496] -> [('MG1_Gen1', '[0.1445]'), ('MG1_ESS1', '[0.1496]')]
# [VectorDecomposition] [-0.9191 -0.5556 -0.7514] -> [('MG2_Gen1', '[-0.9191]'), ('MG2_Gen2', '[-0.5556]'), ('MG2_ESS1', '[-0.7514]')]
# [VectorDecomposition] [ 0.1535 -0.0577  0.1614] -> [('MG3_Gen1', '[0.1535]'), ('MG3_ESS1', '[-0.0577]'), ('MG3_ESS2', '[0.1614]')]
# [VectorDecomposition] [0.1903 0.3763] -> [('MG1_Gen1', '[0.1903]'), ('MG1_ESS1', '[0.3763]')]
# [VectorDecomposition] [-0.7976 -0.8893 -0.9645] -> [('MG2_Gen1', '[-0.7976]'), ('MG2_Gen2', '[-0.8893]'), ('MG2_ESS1', '[-0.9645]')]
# [VectorDecomposition] [ 0.2218 -0.1132 -0.0866] -> [('MG3_Gen1', '[0.2218]'), ('MG3_ESS1', '[-0.1132]'), ('MG3_ESS2', '[-0.0866]')]
# [VectorDecomposition] [0.2972 0.4248] -> [('MG1_Gen1', '[0.2972]'), ('MG1_ESS1', '[0.4248]')]
# [VectorDecomposition] [-0.7532 -0.6705 -0.8621] -> [('MG2_Gen1', '[-0.7532]'), ('MG2_Gen2', '[-0.6705]'), ('MG2_ESS1', '[-0.8621]')]
# [VectorDecomposition] [ 0.4805 -0.0063 -0.2383] -> [('MG3_Gen1', '[0.4805]'), ('MG3_ESS1', '[-0.0063]'), ('MG3_ESS2', '[-0.2383]')]
# [VectorDecomposition] [0.244  0.2782] -> [('MG1_Gen1', '[0.244]'), ('MG1_ESS1', '[0.2782]')]
# [VectorDecomposition] [-0.6647 -0.6047 -0.4609] -> [('MG2_Gen1', '[-0.6647]'), ('MG2_Gen2', '[-0.6047]'), ('MG2_ESS1', '[-0.4609]')]
# [VectorDecomposition] [ 0.0832 -0.2946 -0.2651] -> [('MG3_Gen1', '[0.0832]'), ('MG3_ESS1', '[-0.2946]'), ('MG3_ESS2', '[-0.2651]')]
# [VectorDecomposition] [0.1954 0.4184] -> [('MG1_Gen1', '[0.1954]'), ('MG1_ESS1', '[0.4184]')]
# [VectorDecomposition] [-0.8005 -1.     -0.8492] -> [('MG2_Gen1', '[-0.8005]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.8492]')]
# [VectorDecomposition] [ 0.46   -0.0597 -0.1376] -> [('MG3_Gen1', '[0.46]'), ('MG3_ESS1', '[-0.0597]'), ('MG3_ESS2', '[-0.1376]')]
# [VectorDecomposition] [0.1388 0.256 ] -> [('MG1_Gen1', '[0.1388]'), ('MG1_ESS1', '[0.256]')]
# [VectorDecomposition] [-0.7476 -0.727  -0.7009] -> [('MG2_Gen1', '[-0.7476]'), ('MG2_Gen2', '[-0.727]'), ('MG2_ESS1', '[-0.7009]')]
# [VectorDecomposition] [ 0.3651 -0.1921 -0.2016] -> [('MG3_Gen1', '[0.3651]'), ('MG3_ESS1', '[-0.1921]'), ('MG3_ESS2', '[-0.2016]')]
# [VectorDecomposition] [0.1906 0.4526] -> [('MG1_Gen1', '[0.1906]'), ('MG1_ESS1', '[0.4526]')]
# [VectorDecomposition] [-0.6464 -0.7979 -0.8349] -> [('MG2_Gen1', '[-0.6464]'), ('MG2_Gen2', '[-0.7979]'), ('MG2_ESS1', '[-0.8349]')]
# [VectorDecomposition] [ 0.2771 -0.0369 -0.2851] -> [('MG3_Gen1', '[0.2771]'), ('MG3_ESS1', '[-0.0369]'), ('MG3_ESS2', '[-0.2851]')]
# [VectorDecomposition] [0.1207 0.2923] -> [('MG1_Gen1', '[0.1207]'), ('MG1_ESS1', '[0.2923]')]
# [VectorDecomposition] [-0.9124 -0.7209 -0.8422] -> [('MG2_Gen1', '[-0.9124]'), ('MG2_Gen2', '[-0.7209]'), ('MG2_ESS1', '[-0.8422]')]
# [VectorDecomposition] [ 0.5585 -0.0361 -0.2171] -> [('MG3_Gen1', '[0.5585]'), ('MG3_ESS1', '[-0.0361]'), ('MG3_ESS2', '[-0.2171]')]
# [VectorDecomposition] [0.0092 0.3088] -> [('MG1_Gen1', '[0.0092]'), ('MG1_ESS1', '[0.3088]')]
# [VectorDecomposition] [-0.7067 -0.9564 -0.8074] -> [('MG2_Gen1', '[-0.7067]'), ('MG2_Gen2', '[-0.9564]'), ('MG2_ESS1', '[-0.8074]')]
# [VectorDecomposition] [ 0.3871 -0.303  -0.2607] -> [('MG3_Gen1', '[0.3871]'), ('MG3_ESS1', '[-0.303]'), ('MG3_ESS2', '[-0.2607]')]
# [VectorDecomposition] [0.3001 0.1521] -> [('MG1_Gen1', '[0.3001]'), ('MG1_ESS1', '[0.1521]')]
# [VectorDecomposition] [-0.7373 -0.9975 -0.7514] -> [('MG2_Gen1', '[-0.7373]'), ('MG2_Gen2', '[-0.9975]'), ('MG2_ESS1', '[-0.7514]')]
# [VectorDecomposition] [ 0.1705  0.0598 -0.3089] -> [('MG3_Gen1', '[0.1705]'), ('MG3_ESS1', '[0.0598]'), ('MG3_ESS2', '[-0.3089]')]
# [VectorDecomposition] [0.1674 0.1739] -> [('MG1_Gen1', '[0.1674]'), ('MG1_ESS1', '[0.1739]')]
# [VectorDecomposition] [-0.59   -0.5003 -1.    ] -> [('MG2_Gen1', '[-0.59]'), ('MG2_Gen2', '[-0.5003]'), ('MG2_ESS1', '[-1.]')]
# [VectorDecomposition] [ 0.6055  0.1379 -0.3339] -> [('MG3_Gen1', '[0.6055]'), ('MG3_ESS1', '[0.1379]'), ('MG3_ESS2', '[-0.3339]')]
# [VectorDecomposition] [-0.0068  0.4139] -> [('MG1_Gen1', '[-0.0068]'), ('MG1_ESS1', '[0.4139]')]
# [VectorDecomposition] [-0.8917 -0.9539 -1.    ] -> [('MG2_Gen1', '[-0.8917]'), ('MG2_Gen2', '[-0.9539]'), ('MG2_ESS1', '[-1.]')]
# [VectorDecomposition] [ 0.5303  0.0012 -0.4922] -> [('MG3_Gen1', '[0.5303]'), ('MG3_ESS1', '[0.0012]'), ('MG3_ESS2', '[-0.4922]')]
# [VectorDecomposition] [0.2519 0.1091] -> [('MG1_Gen1', '[0.2519]'), ('MG1_ESS1', '[0.1091]')]
# [VectorDecomposition] [-0.6584 -0.7795 -0.7586] -> [('MG2_Gen1', '[-0.6584]'), ('MG2_Gen2', '[-0.7795]'), ('MG2_ESS1', '[-0.7586]')]
# [VectorDecomposition] [ 0.4328  0.0155 -0.2889] -> [('MG3_Gen1', '[0.4328]'), ('MG3_ESS1', '[0.0155]'), ('MG3_ESS2', '[-0.2889]')]
# [VectorDecomposition] [0.2505 0.3085] -> [('MG1_Gen1', '[0.2505]'), ('MG1_ESS1', '[0.3085]')]
# [VectorDecomposition] [-0.8104 -0.734  -0.7427] -> [('MG2_Gen1', '[-0.8104]'), ('MG2_Gen2', '[-0.734]'), ('MG2_ESS1', '[-0.7427]')]
# [VectorDecomposition] [ 0.5515 -0.1609 -0.7682] -> [('MG3_Gen1', '[0.5515]'), ('MG3_ESS1', '[-0.1609]'), ('MG3_ESS2', '[-0.7682]')]
# [VectorDecomposition] [0.3265 0.6143] -> [('MG1_Gen1', '[0.3265]'), ('MG1_ESS1', '[0.6143]')]
# [VectorDecomposition] [-0.755  -0.8351 -0.7936] -> [('MG2_Gen1', '[-0.755]'), ('MG2_Gen2', '[-0.8351]'), ('MG2_ESS1', '[-0.7936]')]
# [VectorDecomposition] [ 0.4485 -0.1186 -0.5998] -> [('MG3_Gen1', '[0.4485]'), ('MG3_ESS1', '[-0.1186]'), ('MG3_ESS2', '[-0.5998]')]
# [VectorDecomposition] [0.0937 0.1417] -> [('MG1_Gen1', '[0.0937]'), ('MG1_ESS1', '[0.1417]')]
# [VectorDecomposition] [-0.7705 -0.8569 -0.6876] -> [('MG2_Gen1', '[-0.7705]'), ('MG2_Gen2', '[-0.8569]'), ('MG2_ESS1', '[-0.6876]')]
# [VectorDecomposition] [ 0.4524  0.0284 -0.4237] -> [('MG3_Gen1', '[0.4524]'), ('MG3_ESS1', '[0.0284]'), ('MG3_ESS2', '[-0.4237]')]
# [VectorDecomposition] [ 0.4999 -0.0003] -> [('MG1_Gen1', '[0.4999]'), ('MG1_ESS1', '[-0.0003]')]
# [VectorDecomposition] [-0.8996 -0.6742 -0.3795] -> [('MG2_Gen1', '[-0.8996]'), ('MG2_Gen2', '[-0.6742]'), ('MG2_ESS1', '[-0.3795]')]
# [VectorDecomposition] [ 0.4462 -0.1131 -0.4941] -> [('MG3_Gen1', '[0.4462]'), ('MG3_ESS1', '[-0.1131]'), ('MG3_ESS2', '[-0.4941]')]
# [VectorDecomposition] [0.3685 0.2537] -> [('MG1_Gen1', '[0.3685]'), ('MG1_ESS1', '[0.2537]')]
# [VectorDecomposition] [-0.7239 -0.8687 -0.9662] -> [('MG2_Gen1', '[-0.7239]'), ('MG2_Gen2', '[-0.8687]'), ('MG2_ESS1', '[-0.9662]')]
# [VectorDecomposition] [ 0.5442 -0.0395 -0.2862] -> [('MG3_Gen1', '[0.5442]'), ('MG3_ESS1', '[-0.0395]'), ('MG3_ESS2', '[-0.2862]')]
# [VectorDecomposition] [0.1541 0.1999] -> [('MG1_Gen1', '[0.1541]'), ('MG1_ESS1', '[0.1999]')]
# [VectorDecomposition] [-0.7199 -0.7751 -0.7167] -> [('MG2_Gen1', '[-0.7199]'), ('MG2_Gen2', '[-0.7751]'), ('MG2_ESS1', '[-0.7167]')]
# [VectorDecomposition] [ 0.4924  0.0602 -0.4295] -> [('MG3_Gen1', '[0.4924]'), ('MG3_ESS1', '[0.0602]'), ('MG3_ESS2', '[-0.4295]')]
# [VectorDecomposition] [0.1837 0.228 ] -> [('MG1_Gen1', '[0.1837]'), ('MG1_ESS1', '[0.228]')]
# [VectorDecomposition] [-1.     -0.4807 -0.9153] -> [('MG2_Gen1', '[-1.]'), ('MG2_Gen2', '[-0.4807]'), ('MG2_ESS1', '[-0.9153]')]
# [VectorDecomposition] [-0.0458  0.0862 -0.2323] -> [('MG3_Gen1', '[-0.0458]'), ('MG3_ESS1', '[0.0862]'), ('MG3_ESS2', '[-0.2323]')]
# [VectorDecomposition] [0.0447 0.1451] -> [('MG1_Gen1', '[0.0447]'), ('MG1_ESS1', '[0.1451]')]
# [VectorDecomposition] [-0.7544 -0.4924 -0.7758] -> [('MG2_Gen1', '[-0.7544]'), ('MG2_Gen2', '[-0.4924]'), ('MG2_ESS1', '[-0.7758]')]
# [VectorDecomposition] [-0.0798  0.0692 -0.1214] -> [('MG3_Gen1', '[-0.0798]'), ('MG3_ESS1', '[0.0692]'), ('MG3_ESS2', '[-0.1214]')]
# [VectorDecomposition] [0.2035 0.4495] -> [('MG1_Gen1', '[0.2035]'), ('MG1_ESS1', '[0.4495]')]
# [VectorDecomposition] [-0.9576 -0.8462 -0.9275] -> [('MG2_Gen1', '[-0.9576]'), ('MG2_Gen2', '[-0.8462]'), ('MG2_ESS1', '[-0.9275]')]
# [VectorDecomposition] [ 0.0833  0.0229 -0.1893] -> [('MG3_Gen1', '[0.0833]'), ('MG3_ESS1', '[0.0229]'), ('MG3_ESS2', '[-0.1893]')]
# [VectorDecomposition] [0.1511 0.2458] -> [('MG1_Gen1', '[0.1511]'), ('MG1_ESS1', '[0.2458]')]
# [VectorDecomposition] [-0.8738 -0.9665 -0.9418] -> [('MG2_Gen1', '[-0.8738]'), ('MG2_Gen2', '[-0.9665]'), ('MG2_ESS1', '[-0.9418]')]
# [VectorDecomposition] [ 0.0893 -0.0563  0.2864] -> [('MG3_Gen1', '[0.0893]'), ('MG3_ESS1', '[-0.0563]'), ('MG3_ESS2', '[0.2864]')]
# [VectorDecomposition] [-0.1592  0.2956] -> [('MG1_Gen1', '[-0.1592]'), ('MG1_ESS1', '[0.2956]')]
# [VectorDecomposition] [-0.7064 -0.5799 -0.6419] -> [('MG2_Gen1', '[-0.7064]'), ('MG2_Gen2', '[-0.5799]'), ('MG2_ESS1', '[-0.6419]')]
# [VectorDecomposition] [ 0.0184 -0.0207  0.0014] -> [('MG3_Gen1', '[0.0184]'), ('MG3_ESS1', '[-0.0207]'), ('MG3_ESS2', '[0.0014]')]
# [VectorDecomposition] [0.1669 0.383 ] -> [('MG1_Gen1', '[0.1669]'), ('MG1_ESS1', '[0.383]')]
# [VectorDecomposition] [-1.     -0.5844 -0.5714] -> [('MG2_Gen1', '[-1.]'), ('MG2_Gen2', '[-0.5844]'), ('MG2_ESS1', '[-0.5714]')]
# [VectorDecomposition] [ 0.0993  0.0726 -0.0773] -> [('MG3_Gen1', '[0.0993]'), ('MG3_ESS1', '[0.0726]'), ('MG3_ESS2', '[-0.0773]')]
# [VectorDecomposition] [0.079  0.2925] -> [('MG1_Gen1', '[0.079]'), ('MG1_ESS1', '[0.2925]')]
# [VectorDecomposition] [-0.6722 -0.8767 -0.8231] -> [('MG2_Gen1', '[-0.6722]'), ('MG2_Gen2', '[-0.8767]'), ('MG2_ESS1', '[-0.8231]')]
# [VectorDecomposition] [0.1546 0.0451 0.0999] -> [('MG3_Gen1', '[0.1546]'), ('MG3_ESS1', '[0.0451]'), ('MG3_ESS2', '[0.0999]')]
# [VectorDecomposition] [0.1108 0.3517] -> [('MG1_Gen1', '[0.1108]'), ('MG1_ESS1', '[0.3517]')]
# [VectorDecomposition] [-0.7598 -1.     -0.8111] -> [('MG2_Gen1', '[-0.7598]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.8111]')]
# [VectorDecomposition] [ 0.1642 -0.0222 -0.054 ] -> [('MG3_Gen1', '[0.1642]'), ('MG3_ESS1', '[-0.0222]'), ('MG3_ESS2', '[-0.054]')]
# [VectorDecomposition] [-0.0992  0.2842] -> [('MG1_Gen1', '[-0.0992]'), ('MG1_ESS1', '[0.2842]')]
# [VectorDecomposition] [-0.8635 -1.     -0.6424] -> [('MG2_Gen1', '[-0.8635]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.6424]')]
# [VectorDecomposition] [ 0.2968 -0.112   0.0206] -> [('MG3_Gen1', '[0.2968]'), ('MG3_ESS1', '[-0.112]'), ('MG3_ESS2', '[0.0206]')]
# [VectorDecomposition] [0.155  0.2802] -> [('MG1_Gen1', '[0.155]'), ('MG1_ESS1', '[0.2802]')]
# [VectorDecomposition] [-0.9186 -0.5433 -1.    ] -> [('MG2_Gen1', '[-0.9186]'), ('MG2_Gen2', '[-0.5433]'), ('MG2_ESS1', '[-1.]')]
# [VectorDecomposition] [ 0.1959  0.087  -0.4271] -> [('MG3_Gen1', '[0.1959]'), ('MG3_ESS1', '[0.087]'), ('MG3_ESS2', '[-0.4271]')]
# [VectorDecomposition] [0.1742 0.2676] -> [('MG1_Gen1', '[0.1742]'), ('MG1_ESS1', '[0.2676]')]
# [VectorDecomposition] [-0.7088 -0.6455 -0.839 ] -> [('MG2_Gen1', '[-0.7088]'), ('MG2_Gen2', '[-0.6455]'), ('MG2_ESS1', '[-0.839]')]
# [VectorDecomposition] [0.0191 0.1923 0.0518] -> [('MG3_Gen1', '[0.0191]'), ('MG3_ESS1', '[0.1923]'), ('MG3_ESS2', '[0.0518]')]
# [VectorDecomposition] [0.1334 0.3319] -> [('MG1_Gen1', '[0.1334]'), ('MG1_ESS1', '[0.3319]')]
# [VectorDecomposition] [-0.7707 -0.7501 -0.7503] -> [('MG2_Gen1', '[-0.7707]'), ('MG2_Gen2', '[-0.7501]'), ('MG2_ESS1', '[-0.7503]')]
# [VectorDecomposition] [ 0.4771 -0.2756 -0.0163] -> [('MG3_Gen1', '[0.4771]'), ('MG3_ESS1', '[-0.2756]'), ('MG3_ESS2', '[-0.0163]')]
# [VectorDecomposition] [0.2595 0.2459] -> [('MG1_Gen1', '[0.2595]'), ('MG1_ESS1', '[0.2459]')]
# [VectorDecomposition] [-0.6334 -1.     -0.5891] -> [('MG2_Gen1', '[-0.6334]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.5891]')]
# [VectorDecomposition] [ 0.3659 -0.1986 -0.1611] -> [('MG3_Gen1', '[0.3659]'), ('MG3_ESS1', '[-0.1986]'), ('MG3_ESS2', '[-0.1611]')]
# [VectorDecomposition] [0.1551 0.667 ] -> [('MG1_Gen1', '[0.1551]'), ('MG1_ESS1', '[0.667]')]
# [VectorDecomposition] [-0.4991 -0.7334 -0.8379] -> [('MG2_Gen1', '[-0.4991]'), ('MG2_Gen2', '[-0.7334]'), ('MG2_ESS1', '[-0.8379]')]
# [VectorDecomposition] [ 0.2443 -0.0798 -0.3561] -> [('MG3_Gen1', '[0.2443]'), ('MG3_ESS1', '[-0.0798]'), ('MG3_ESS2', '[-0.3561]')]
# [VectorDecomposition] [0.0684 0.1913] -> [('MG1_Gen1', '[0.0684]'), ('MG1_ESS1', '[0.1913]')]
# [VectorDecomposition] [-0.8666 -0.9158 -0.888 ] -> [('MG2_Gen1', '[-0.8666]'), ('MG2_Gen2', '[-0.9158]'), ('MG2_ESS1', '[-0.888]')]
# [VectorDecomposition] [ 0.2062  0.3534 -0.5056] -> [('MG3_Gen1', '[0.2062]'), ('MG3_ESS1', '[0.3534]'), ('MG3_ESS2', '[-0.5056]')]
# [VectorDecomposition] [0.0537 0.3401] -> [('MG1_Gen1', '[0.0537]'), ('MG1_ESS1', '[0.3401]')]
# [VectorDecomposition] [-0.8199 -0.726  -0.6075] -> [('MG2_Gen1', '[-0.8199]'), ('MG2_Gen2', '[-0.726]'), ('MG2_ESS1', '[-0.6075]')]
# [VectorDecomposition] [ 0.5962  0.0682 -0.4886] -> [('MG3_Gen1', '[0.5962]'), ('MG3_ESS1', '[0.0682]'), ('MG3_ESS2', '[-0.4886]')]
# [VectorDecomposition] [0.3707 0.0133] -> [('MG1_Gen1', '[0.3707]'), ('MG1_ESS1', '[0.0133]')]
# [VectorDecomposition] [-0.8257 -0.8907 -0.9187] -> [('MG2_Gen1', '[-0.8257]'), ('MG2_Gen2', '[-0.8907]'), ('MG2_ESS1', '[-0.9187]')]
# [VectorDecomposition] [ 0.5103 -0.0722 -0.1936] -> [('MG3_Gen1', '[0.5103]'), ('MG3_ESS1', '[-0.0722]'), ('MG3_ESS2', '[-0.1936]')]
# [VectorDecomposition] [-0.022  0.413] -> [('MG1_Gen1', '[-0.022]'), ('MG1_ESS1', '[0.413]')]
# [VectorDecomposition] [-0.7055 -0.777  -0.9447] -> [('MG2_Gen1', '[-0.7055]'), ('MG2_Gen2', '[-0.777]'), ('MG2_ESS1', '[-0.9447]')]
# [VectorDecomposition] [ 0.396  -0.2724 -0.6696] -> [('MG3_Gen1', '[0.396]'), ('MG3_ESS1', '[-0.2724]'), ('MG3_ESS2', '[-0.6696]')]
# [VectorDecomposition] [0.6959 0.417 ] -> [('MG1_Gen1', '[0.6959]'), ('MG1_ESS1', '[0.417]')]
# [VectorDecomposition] [-0.5409 -0.8831 -0.659 ] -> [('MG2_Gen1', '[-0.5409]'), ('MG2_Gen2', '[-0.8831]'), ('MG2_ESS1', '[-0.659]')]
# [VectorDecomposition] [ 0.5828  0.0656 -0.4069] -> [('MG3_Gen1', '[0.5828]'), ('MG3_ESS1', '[0.0656]'), ('MG3_ESS2', '[-0.4069]')]
# [VectorDecomposition] [ 0.1586 -0.0076] -> [('MG1_Gen1', '[0.1586]'), ('MG1_ESS1', '[-0.0076]')]
# [VectorDecomposition] [-0.7083 -0.7569 -0.5921] -> [('MG2_Gen1', '[-0.7083]'), ('MG2_Gen2', '[-0.7569]'), ('MG2_ESS1', '[-0.5921]')]
# [VectorDecomposition] [ 0.4496  0.2297 -0.4828] -> [('MG3_Gen1', '[0.4496]'), ('MG3_ESS1', '[0.2297]'), ('MG3_ESS2', '[-0.4828]')]
# [VectorDecomposition] [0.0158 0.4211] -> [('MG1_Gen1', '[0.0158]'), ('MG1_ESS1', '[0.4211]')]
# [VectorDecomposition] [-0.8798 -1.     -0.7468] -> [('MG2_Gen1', '[-0.8798]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.7468]')]
# [VectorDecomposition] [ 0.6396 -0.0088 -0.3783] -> [('MG3_Gen1', '[0.6396]'), ('MG3_ESS1', '[-0.0088]'), ('MG3_ESS2', '[-0.3783]')]
# [VectorDecomposition] [0.8181 0.4002] -> [('MG1_Gen1', '[0.8181]'), ('MG1_ESS1', '[0.4002]')]
# [VectorDecomposition] [-0.5268 -1.     -0.6555] -> [('MG2_Gen1', '[-0.5268]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.6555]')]
# [VectorDecomposition] [ 0.644  -0.0996 -0.5821] -> [('MG3_Gen1', '[0.644]'), ('MG3_ESS1', '[-0.0996]'), ('MG3_ESS2', '[-0.5821]')]
# [VectorDecomposition] [0.2495 0.2625] -> [('MG1_Gen1', '[0.2495]'), ('MG1_ESS1', '[0.2625]')]
# [VectorDecomposition] [-0.867  -0.6369 -0.5416] -> [('MG2_Gen1', '[-0.867]'), ('MG2_Gen2', '[-0.6369]'), ('MG2_ESS1', '[-0.5416]')]
# [VectorDecomposition] [ 0.5888 -0.1076 -0.3913] -> [('MG3_Gen1', '[0.5888]'), ('MG3_ESS1', '[-0.1076]'), ('MG3_ESS2', '[-0.3913]')]
# [VectorDecomposition] [0.3242 0.3815] -> [('MG1_Gen1', '[0.3242]'), ('MG1_ESS1', '[0.3815]')]
# [VectorDecomposition] [-1.     -0.874  -0.7167] -> [('MG2_Gen1', '[-1.]'), ('MG2_Gen2', '[-0.874]'), ('MG2_ESS1', '[-0.7167]')]
# [VectorDecomposition] [ 0.6526  0.1107 -0.3729] -> [('MG3_Gen1', '[0.6526]'), ('MG3_ESS1', '[0.1107]'), ('MG3_ESS2', '[-0.3729]')]
# [VectorDecomposition] [0.537  0.3167] -> [('MG1_Gen1', '[0.537]'), ('MG1_ESS1', '[0.3167]')]
# [VectorDecomposition] [-0.6735 -1.     -0.6795] -> [('MG2_Gen1', '[-0.6735]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.6795]')]
# [VectorDecomposition] [-0.0075  0.0157 -0.1222] -> [('MG3_Gen1', '[-0.0075]'), ('MG3_ESS1', '[0.0157]'), ('MG3_ESS2', '[-0.1222]')]
# [VectorDecomposition] [0.2141 0.2367] -> [('MG1_Gen1', '[0.2141]'), ('MG1_ESS1', '[0.2367]')]
# [VectorDecomposition] [-0.9575 -0.6682 -0.5884] -> [('MG2_Gen1', '[-0.9575]'), ('MG2_Gen2', '[-0.6682]'), ('MG2_ESS1', '[-0.5884]')]
# [VectorDecomposition] [ 0.2816  0.0174 -0.0624] -> [('MG3_Gen1', '[0.2816]'), ('MG3_ESS1', '[0.0174]'), ('MG3_ESS2', '[-0.0624]')]
# [VectorDecomposition] [0.1462 0.0668] -> [('MG1_Gen1', '[0.1462]'), ('MG1_ESS1', '[0.0668]')]
# [VectorDecomposition] [-0.6601 -0.9793 -0.9253] -> [('MG2_Gen1', '[-0.6601]'), ('MG2_Gen2', '[-0.9793]'), ('MG2_ESS1', '[-0.9253]')]
# [VectorDecomposition] [-0.0006  0.2276  0.0323] -> [('MG3_Gen1', '[-0.0006]'), ('MG3_ESS1', '[0.2276]'), ('MG3_ESS2', '[0.0323]')]
# [VectorDecomposition] [0.0779 0.1875] -> [('MG1_Gen1', '[0.0779]'), ('MG1_ESS1', '[0.1875]')]
# [VectorDecomposition] [-0.676  -0.8261 -0.8371] -> [('MG2_Gen1', '[-0.676]'), ('MG2_Gen2', '[-0.8261]'), ('MG2_ESS1', '[-0.8371]')]
# [VectorDecomposition] [0.0638 0.1016 0.2537] -> [('MG3_Gen1', '[0.0638]'), ('MG3_ESS1', '[0.1016]'), ('MG3_ESS2', '[0.2537]')]
# [VectorDecomposition] [0.048  0.1982] -> [('MG1_Gen1', '[0.048]'), ('MG1_ESS1', '[0.1982]')]
# [VectorDecomposition] [-0.9143 -1.     -0.8849] -> [('MG2_Gen1', '[-0.9143]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.8849]')]
# [VectorDecomposition] [-0.0128  0.1579 -0.0906] -> [('MG3_Gen1', '[-0.0128]'), ('MG3_ESS1', '[0.1579]'), ('MG3_ESS2', '[-0.0906]')]
# [VectorDecomposition] [-0.0069  0.3854] -> [('MG1_Gen1', '[-0.0069]'), ('MG1_ESS1', '[0.3854]')]
# [VectorDecomposition] [-0.7986 -1.     -0.7853] -> [('MG2_Gen1', '[-0.7986]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.7853]')]
# [VectorDecomposition] [ 0.0917 -0.1438 -0.0897] -> [('MG3_Gen1', '[0.0917]'), ('MG3_ESS1', '[-0.1438]'), ('MG3_ESS2', '[-0.0897]')]
# [VectorDecomposition] [-0.0971  0.2486] -> [('MG1_Gen1', '[-0.0971]'), ('MG1_ESS1', '[0.2486]')]
# [VectorDecomposition] [-0.6048 -0.6621 -0.5439] -> [('MG2_Gen1', '[-0.6048]'), ('MG2_Gen2', '[-0.6621]'), ('MG2_ESS1', '[-0.5439]')]
# [VectorDecomposition] [ 0.3746  0.2007 -0.283 ] -> [('MG3_Gen1', '[0.3746]'), ('MG3_ESS1', '[0.2007]'), ('MG3_ESS2', '[-0.283]')]
# [VectorDecomposition] [0.3635 0.0104] -> [('MG1_Gen1', '[0.3635]'), ('MG1_ESS1', '[0.0104]')]
# [VectorDecomposition] [-0.9152 -1.     -0.6232] -> [('MG2_Gen1', '[-0.9152]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.6232]')]
# [VectorDecomposition] [ 0.4464 -0.059   0.1188] -> [('MG3_Gen1', '[0.4464]'), ('MG3_ESS1', '[-0.059]'), ('MG3_ESS2', '[0.1188]')]
# [VectorDecomposition] [0.1241 0.3233] -> [('MG1_Gen1', '[0.1241]'), ('MG1_ESS1', '[0.3233]')]
# [VectorDecomposition] [-0.7233 -0.9348 -0.6323] -> [('MG2_Gen1', '[-0.7233]'), ('MG2_Gen2', '[-0.9348]'), ('MG2_ESS1', '[-0.6323]')]
# [VectorDecomposition] [ 0.5499 -0.176  -0.0367] -> [('MG3_Gen1', '[0.5499]'), ('MG3_ESS1', '[-0.176]'), ('MG3_ESS2', '[-0.0367]')]
# [VectorDecomposition] [0.2073 0.5539] -> [('MG1_Gen1', '[0.2073]'), ('MG1_ESS1', '[0.5539]')]
# [VectorDecomposition] [-0.7011 -0.7024 -0.631 ] -> [('MG2_Gen1', '[-0.7011]'), ('MG2_Gen2', '[-0.7024]'), ('MG2_ESS1', '[-0.631]')]
# [VectorDecomposition] [ 0.3227 -0.2382 -0.0052] -> [('MG3_Gen1', '[0.3227]'), ('MG3_ESS1', '[-0.2382]'), ('MG3_ESS2', '[-0.0052]')]
# [VectorDecomposition] [0.0245 0.3306] -> [('MG1_Gen1', '[0.0245]'), ('MG1_ESS1', '[0.3306]')]
# [VectorDecomposition] [-0.7239 -0.9554 -0.744 ] -> [('MG2_Gen1', '[-0.7239]'), ('MG2_Gen2', '[-0.9554]'), ('MG2_ESS1', '[-0.744]')]
# [VectorDecomposition] [ 0.4848 -0.0443 -0.4064] -> [('MG3_Gen1', '[0.4848]'), ('MG3_ESS1', '[-0.0443]'), ('MG3_ESS2', '[-0.4064]')]
# [VectorDecomposition] [-0.1969  0.1457] -> [('MG1_Gen1', '[-0.1969]'), ('MG1_ESS1', '[0.1457]')]
# [VectorDecomposition] [-0.8559 -0.8761 -0.8642] -> [('MG2_Gen1', '[-0.8559]'), ('MG2_Gen2', '[-0.8761]'), ('MG2_ESS1', '[-0.8642]')]
# [VectorDecomposition] [ 0.3708 -0.1175 -0.2922] -> [('MG3_Gen1', '[0.3708]'), ('MG3_ESS1', '[-0.1175]'), ('MG3_ESS2', '[-0.2922]')]
# [VectorDecomposition] [0.3421 0.1561] -> [('MG1_Gen1', '[0.3421]'), ('MG1_ESS1', '[0.1561]')]
# [VectorDecomposition] [-0.8192 -0.4797 -0.5959] -> [('MG2_Gen1', '[-0.8192]'), ('MG2_Gen2', '[-0.4797]'), ('MG2_ESS1', '[-0.5959]')]
# [VectorDecomposition] [ 0.1388 -0.0446 -0.2183] -> [('MG3_Gen1', '[0.1388]'), ('MG3_ESS1', '[-0.0446]'), ('MG3_ESS2', '[-0.2183]')]
# [VectorDecomposition] [0.4065 0.3223] -> [('MG1_Gen1', '[0.4065]'), ('MG1_ESS1', '[0.3223]')]
# [VectorDecomposition] [-0.9196 -0.956  -0.6915] -> [('MG2_Gen1', '[-0.9196]'), ('MG2_Gen2', '[-0.956]'), ('MG2_ESS1', '[-0.6915]')]
# [VectorDecomposition] [ 0.3847 -0.0993 -0.3412] -> [('MG3_Gen1', '[0.3847]'), ('MG3_ESS1', '[-0.0993]'), ('MG3_ESS2', '[-0.3412]')]
# [VectorDecomposition] [0.1615 0.4098] -> [('MG1_Gen1', '[0.1615]'), ('MG1_ESS1', '[0.4098]')]
# [VectorDecomposition] [-0.8566 -0.7108 -0.5792] -> [('MG2_Gen1', '[-0.8566]'), ('MG2_Gen2', '[-0.7108]'), ('MG2_ESS1', '[-0.5792]')]
# [VectorDecomposition] [ 0.4255 -0.1431 -0.1254] -> [('MG3_Gen1', '[0.4255]'), ('MG3_ESS1', '[-0.1431]'), ('MG3_ESS2', '[-0.1254]')]
# [VectorDecomposition] [0.1285 0.3567] -> [('MG1_Gen1', '[0.1285]'), ('MG1_ESS1', '[0.3567]')]
# [VectorDecomposition] [-0.9156 -1.     -0.7187] -> [('MG2_Gen1', '[-0.9156]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.7187]')]
# [VectorDecomposition] [ 0.417  -0.0241 -0.3045] -> [('MG3_Gen1', '[0.417]'), ('MG3_ESS1', '[-0.0241]'), ('MG3_ESS2', '[-0.3045]')]
# [VectorDecomposition] [0.1341 0.1836] -> [('MG1_Gen1', '[0.1341]'), ('MG1_ESS1', '[0.1836]')]
# [VectorDecomposition] [-0.7707 -0.4954 -0.5766] -> [('MG2_Gen1', '[-0.7707]'), ('MG2_Gen2', '[-0.4954]'), ('MG2_ESS1', '[-0.5766]')]
# [VectorDecomposition] [ 0.3015  0.0742 -0.4188] -> [('MG3_Gen1', '[0.3015]'), ('MG3_ESS1', '[0.0742]'), ('MG3_ESS2', '[-0.4188]')]
# [VectorDecomposition] [0.1622 0.4197] -> [('MG1_Gen1', '[0.1622]'), ('MG1_ESS1', '[0.4197]')]
# [VectorDecomposition] [-0.9189 -1.     -0.922 ] -> [('MG2_Gen1', '[-0.9189]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.922]')]
# [VectorDecomposition] [ 0.4046  0.0086 -0.1774] -> [('MG3_Gen1', '[0.4046]'), ('MG3_ESS1', '[0.0086]'), ('MG3_ESS2', '[-0.1774]')]
# [VectorDecomposition] [0.1229 0.4018] -> [('MG1_Gen1', '[0.1229]'), ('MG1_ESS1', '[0.4018]')]
# [VectorDecomposition] [-0.6827 -0.7993 -0.5732] -> [('MG2_Gen1', '[-0.6827]'), ('MG2_Gen2', '[-0.7993]'), ('MG2_ESS1', '[-0.5732]')]
# [VectorDecomposition] [ 0.4657 -0.1392 -0.2024] -> [('MG3_Gen1', '[0.4657]'), ('MG3_ESS1', '[-0.1392]'), ('MG3_ESS2', '[-0.2024]')]
# [VectorDecomposition] [0.0498 0.3012] -> [('MG1_Gen1', '[0.0498]'), ('MG1_ESS1', '[0.3012]')]
# [VectorDecomposition] [-0.7995 -0.7591 -0.8594] -> [('MG2_Gen1', '[-0.7995]'), ('MG2_Gen2', '[-0.7591]'), ('MG2_ESS1', '[-0.8594]')]
# [VectorDecomposition] [ 0.4055 -0.0283 -0.2312] -> [('MG3_Gen1', '[0.4055]'), ('MG3_ESS1', '[-0.0283]'), ('MG3_ESS2', '[-0.2312]')]
# [VectorDecomposition] [0.1154 0.3008] -> [('MG1_Gen1', '[0.1154]'), ('MG1_ESS1', '[0.3008]')]
# [VectorDecomposition] [-0.8383 -1.     -0.3541] -> [('MG2_Gen1', '[-0.8383]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.3541]')]
# [VectorDecomposition] [ 0.4042 -0.2232 -0.1751] -> [('MG3_Gen1', '[0.4042]'), ('MG3_ESS1', '[-0.2232]'), ('MG3_ESS2', '[-0.1751]')]
# [VectorDecomposition] [0.0723 0.347 ] -> [('MG1_Gen1', '[0.0723]'), ('MG1_ESS1', '[0.347]')]
# [VectorDecomposition] [-0.6241 -0.8804 -0.7677] -> [('MG2_Gen1', '[-0.6241]'), ('MG2_Gen2', '[-0.8804]'), ('MG2_ESS1', '[-0.7677]')]
# [VectorDecomposition] [ 0.3584 -0.0152 -0.6477] -> [('MG3_Gen1', '[0.3584]'), ('MG3_ESS1', '[-0.0152]'), ('MG3_ESS2', '[-0.6477]')]
# [VectorDecomposition] [0.0495 0.27  ] -> [('MG1_Gen1', '[0.0495]'), ('MG1_ESS1', '[0.27]')]
# [VectorDecomposition] [-0.6357 -0.7237 -0.4879] -> [('MG2_Gen1', '[-0.6357]'), ('MG2_Gen2', '[-0.7237]'), ('MG2_ESS1', '[-0.4879]')]
# [VectorDecomposition] [ 0.5431 -0.0678 -0.4286] -> [('MG3_Gen1', '[0.5431]'), ('MG3_ESS1', '[-0.0678]'), ('MG3_ESS2', '[-0.4286]')]
# [VectorDecomposition] [-0.067   0.1481] -> [('MG1_Gen1', '[-0.067]'), ('MG1_ESS1', '[0.1481]')]
# [VectorDecomposition] [-0.9658 -0.7938 -0.6717] -> [('MG2_Gen1', '[-0.9658]'), ('MG2_Gen2', '[-0.7938]'), ('MG2_ESS1', '[-0.6717]')]
# [VectorDecomposition] [ 0.3622 -0.0816 -0.6419] -> [('MG3_Gen1', '[0.3622]'), ('MG3_ESS1', '[-0.0816]'), ('MG3_ESS2', '[-0.6419]')]
# [VectorDecomposition] [0.2219 0.3605] -> [('MG1_Gen1', '[0.2219]'), ('MG1_ESS1', '[0.3605]')]
# [VectorDecomposition] [-0.8313 -0.6209 -0.6934] -> [('MG2_Gen1', '[-0.8313]'), ('MG2_Gen2', '[-0.6209]'), ('MG2_ESS1', '[-0.6934]')]
# [VectorDecomposition] [-0.1791 -0.0235  0.0774] -> [('MG3_Gen1', '[-0.1791]'), ('MG3_ESS1', '[-0.0235]'), ('MG3_ESS2', '[0.0774]')]
# [VectorDecomposition] [0.1834 0.1607] -> [('MG1_Gen1', '[0.1834]'), ('MG1_ESS1', '[0.1607]')]
# [VectorDecomposition] [-0.7272 -0.8407 -0.6991] -> [('MG2_Gen1', '[-0.7272]'), ('MG2_Gen2', '[-0.8407]'), ('MG2_ESS1', '[-0.6991]')]
# [VectorDecomposition] [ 0.0948 -0.1053  0.0526] -> [('MG3_Gen1', '[0.0948]'), ('MG3_ESS1', '[-0.1053]'), ('MG3_ESS2', '[0.0526]')]
# [VectorDecomposition] [0.047  0.5554] -> [('MG1_Gen1', '[0.047]'), ('MG1_ESS1', '[0.5554]')]
# [VectorDecomposition] [-0.6814 -0.8027 -0.8808] -> [('MG2_Gen1', '[-0.6814]'), ('MG2_Gen2', '[-0.8027]'), ('MG2_ESS1', '[-0.8808]')]
# [VectorDecomposition] [ 0.0665  0.0864 -0.1868] -> [('MG3_Gen1', '[0.0665]'), ('MG3_ESS1', '[0.0864]'), ('MG3_ESS2', '[-0.1868]')]
# [VectorDecomposition] [0.4713 0.3814] -> [('MG1_Gen1', '[0.4713]'), ('MG1_ESS1', '[0.3814]')]
# [VectorDecomposition] [-0.5485 -0.9812 -0.5059] -> [('MG2_Gen1', '[-0.5485]'), ('MG2_Gen2', '[-0.9812]'), ('MG2_ESS1', '[-0.5059]')]
# [VectorDecomposition] [-0.1173 -0.0308  0.0576] -> [('MG3_Gen1', '[-0.1173]'), ('MG3_ESS1', '[-0.0308]'), ('MG3_ESS2', '[0.0576]')]
# [VectorDecomposition] [ 0.1319 -0.0082] -> [('MG1_Gen1', '[0.1319]'), ('MG1_ESS1', '[-0.0082]')]
# [VectorDecomposition] [-0.9359 -0.684  -0.42  ] -> [('MG2_Gen1', '[-0.9359]'), ('MG2_Gen2', '[-0.684]'), ('MG2_ESS1', '[-0.42]')]
# [VectorDecomposition] [0.2276 0.0278 0.084 ] -> [('MG3_Gen1', '[0.2276]'), ('MG3_ESS1', '[0.0278]'), ('MG3_ESS2', '[0.084]')]
# [VectorDecomposition] [-0.0289  0.4037] -> [('MG1_Gen1', '[-0.0289]'), ('MG1_ESS1', '[0.4037]')]
# [VectorDecomposition] [-1.     -0.8136 -0.7634] -> [('MG2_Gen1', '[-1.]'), ('MG2_Gen2', '[-0.8136]'), ('MG2_ESS1', '[-0.7634]')]
# [VectorDecomposition] [0.2209 0.0262 0.1324] -> [('MG3_Gen1', '[0.2209]'), ('MG3_ESS1', '[0.0262]'), ('MG3_ESS2', '[0.1324]')]
# [VectorDecomposition] [0.1206 0.4483] -> [('MG1_Gen1', '[0.1206]'), ('MG1_ESS1', '[0.4483]')]
# [VectorDecomposition] [-0.6593 -1.     -0.7127] -> [('MG2_Gen1', '[-0.6593]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.7127]')]
# [VectorDecomposition] [ 0.1165 -0.0293 -0.0382] -> [('MG3_Gen1', '[0.1165]'), ('MG3_ESS1', '[-0.0293]'), ('MG3_ESS2', '[-0.0382]')]
# [VectorDecomposition] [-0.0734  0.4127] -> [('MG1_Gen1', '[-0.0734]'), ('MG1_ESS1', '[0.4127]')]
# [VectorDecomposition] [-0.6871 -0.7516 -0.35  ] -> [('MG2_Gen1', '[-0.6871]'), ('MG2_Gen2', '[-0.7516]'), ('MG2_ESS1', '[-0.35]')]
# [VectorDecomposition] [ 0.1651  0.099  -0.1757] -> [('MG3_Gen1', '[0.1651]'), ('MG3_ESS1', '[0.099]'), ('MG3_ESS2', '[-0.1757]')]
# [VectorDecomposition] [0.1963 0.1841] -> [('MG1_Gen1', '[0.1963]'), ('MG1_ESS1', '[0.1841]')]
# [VectorDecomposition] [-0.6187 -0.9183 -0.731 ] -> [('MG2_Gen1', '[-0.6187]'), ('MG2_Gen2', '[-0.9183]'), ('MG2_ESS1', '[-0.731]')]
# [VectorDecomposition] [ 0.4298  0.2615 -0.0365] -> [('MG3_Gen1', '[0.4298]'), ('MG3_ESS1', '[0.2615]'), ('MG3_ESS2', '[-0.0365]')]
# [VectorDecomposition] [0.3392 0.3263] -> [('MG1_Gen1', '[0.3392]'), ('MG1_ESS1', '[0.3263]')]
# [VectorDecomposition] [-0.6636 -0.806  -0.8651] -> [('MG2_Gen1', '[-0.6636]'), ('MG2_Gen2', '[-0.806]'), ('MG2_ESS1', '[-0.8651]')]
# [VectorDecomposition] [ 0.265   0.2221 -0.1552] -> [('MG3_Gen1', '[0.265]'), ('MG3_ESS1', '[0.2221]'), ('MG3_ESS2', '[-0.1552]')]
# [VectorDecomposition] [-0.031   0.2621] -> [('MG1_Gen1', '[-0.031]'), ('MG1_ESS1', '[0.2621]')]
# [VectorDecomposition] [-1.     -0.9079 -0.9054] -> [('MG2_Gen1', '[-1.]'), ('MG2_Gen2', '[-0.9079]'), ('MG2_ESS1', '[-0.9054]')]
# [VectorDecomposition] [ 0.5529  0.0027 -0.3704] -> [('MG3_Gen1', '[0.5529]'), ('MG3_ESS1', '[0.0027]'), ('MG3_ESS2', '[-0.3704]')]
# [VectorDecomposition] [0.2782 0.3015] -> [('MG1_Gen1', '[0.2782]'), ('MG1_ESS1', '[0.3015]')]
# [VectorDecomposition] [-0.7492 -0.7493 -0.6701] -> [('MG2_Gen1', '[-0.7492]'), ('MG2_Gen2', '[-0.7493]'), ('MG2_ESS1', '[-0.6701]')]
# [VectorDecomposition] [ 0.2007  0.2352 -0.0533] -> [('MG3_Gen1', '[0.2007]'), ('MG3_ESS1', '[0.2352]'), ('MG3_ESS2', '[-0.0533]')]
# [VectorDecomposition] [0.0599 0.3125] -> [('MG1_Gen1', '[0.0599]'), ('MG1_ESS1', '[0.3125]')]
# [VectorDecomposition] [-0.9412 -0.7774 -0.6411] -> [('MG2_Gen1', '[-0.9412]'), ('MG2_Gen2', '[-0.7774]'), ('MG2_ESS1', '[-0.6411]')]
# [VectorDecomposition] [ 0.3992  0.1822 -0.2009] -> [('MG3_Gen1', '[0.3992]'), ('MG3_ESS1', '[0.1822]'), ('MG3_ESS2', '[-0.2009]')]
# [VectorDecomposition] [0.3767 0.2997] -> [('MG1_Gen1', '[0.3767]'), ('MG1_ESS1', '[0.2997]')]
# [VectorDecomposition] [-0.7811 -0.8492 -0.7176] -> [('MG2_Gen1', '[-0.7811]'), ('MG2_Gen2', '[-0.8492]'), ('MG2_ESS1', '[-0.7176]')]
# [VectorDecomposition] [ 0.3079  0.3897 -0.1454] -> [('MG3_Gen1', '[0.3079]'), ('MG3_ESS1', '[0.3897]'), ('MG3_ESS2', '[-0.1454]')]
# [VectorDecomposition] [-0.1186  0.2776] -> [('MG1_Gen1', '[-0.1186]'), ('MG1_ESS1', '[0.2776]')]
# [VectorDecomposition] [-0.9909 -0.6747 -0.5283] -> [('MG2_Gen1', '[-0.9909]'), ('MG2_Gen2', '[-0.6747]'), ('MG2_ESS1', '[-0.5283]')]
# [VectorDecomposition] [ 0.3527  0.1744 -0.3089] -> [('MG3_Gen1', '[0.3527]'), ('MG3_ESS1', '[0.1744]'), ('MG3_ESS2', '[-0.3089]')]
# [VectorDecomposition] [0.2156 0.5795] -> [('MG1_Gen1', '[0.2156]'), ('MG1_ESS1', '[0.5795]')]
# [VectorDecomposition] [-0.8516 -0.9904 -0.6354] -> [('MG2_Gen1', '[-0.8516]'), ('MG2_Gen2', '[-0.9904]'), ('MG2_ESS1', '[-0.6354]')]
# [VectorDecomposition] [ 0.5286  0.1869 -0.155 ] -> [('MG3_Gen1', '[0.5286]'), ('MG3_ESS1', '[0.1869]'), ('MG3_ESS2', '[-0.155]')]
# [VectorDecomposition] [0.0352 0.0466] -> [('MG1_Gen1', '[0.0352]'), ('MG1_ESS1', '[0.0466]')]
# [VectorDecomposition] [-0.5971 -0.84   -0.8762] -> [('MG2_Gen1', '[-0.5971]'), ('MG2_Gen2', '[-0.84]'), ('MG2_ESS1', '[-0.8762]')]
# [VectorDecomposition] [ 0.3166  0.2507 -0.3056] -> [('MG3_Gen1', '[0.3166]'), ('MG3_ESS1', '[0.2507]'), ('MG3_ESS2', '[-0.3056]')]
# [VectorDecomposition] [0.1907 0.4546] -> [('MG1_Gen1', '[0.1907]'), ('MG1_ESS1', '[0.4546]')]
# [VectorDecomposition] [-0.8955 -0.9852 -0.8724] -> [('MG2_Gen1', '[-0.8955]'), ('MG2_Gen2', '[-0.9852]'), ('MG2_ESS1', '[-0.8724]')]
# [VectorDecomposition] [ 0.3673  0.0406 -0.5069] -> [('MG3_Gen1', '[0.3673]'), ('MG3_ESS1', '[0.0406]'), ('MG3_ESS2', '[-0.5069]')]
# [VectorDecomposition] [0.1425 0.264 ] -> [('MG1_Gen1', '[0.1425]'), ('MG1_ESS1', '[0.264]')]
# [VectorDecomposition] [-0.7598 -0.681  -0.4897] -> [('MG2_Gen1', '[-0.7598]'), ('MG2_Gen2', '[-0.681]'), ('MG2_ESS1', '[-0.4897]')]
# [VectorDecomposition] [ 0.7649  0.1051 -0.3489] -> [('MG3_Gen1', '[0.7649]'), ('MG3_ESS1', '[0.1051]'), ('MG3_ESS2', '[-0.3489]')]
# [VectorDecomposition] [0.0648 0.4809] -> [('MG1_Gen1', '[0.0648]'), ('MG1_ESS1', '[0.4809]')]
# [VectorDecomposition] [-0.5876 -0.9132 -0.6463] -> [('MG2_Gen1', '[-0.5876]'), ('MG2_Gen2', '[-0.9132]'), ('MG2_ESS1', '[-0.6463]')]
# [VectorDecomposition] [ 0.5048  0.0584 -0.3574] -> [('MG3_Gen1', '[0.5048]'), ('MG3_ESS1', '[0.0584]'), ('MG3_ESS2', '[-0.3574]')]
# [VectorDecomposition] [0.0854 0.4621] -> [('MG1_Gen1', '[0.0854]'), ('MG1_ESS1', '[0.4621]')]
# [VectorDecomposition] [-1.     -0.9142 -0.753 ] -> [('MG2_Gen1', '[-1.]'), ('MG2_Gen2', '[-0.9142]'), ('MG2_ESS1', '[-0.753]')]
# [VectorDecomposition] [ 0.4046  0.1394 -0.6192] -> [('MG3_Gen1', '[0.4046]'), ('MG3_ESS1', '[0.1394]'), ('MG3_ESS2', '[-0.6192]')]
# [VectorDecomposition] [0.1512 0.1194] -> [('MG1_Gen1', '[0.1512]'), ('MG1_ESS1', '[0.1194]')]
# [VectorDecomposition] [-0.7764 -0.7014 -0.3757] -> [('MG2_Gen1', '[-0.7764]'), ('MG2_Gen2', '[-0.7014]'), ('MG2_ESS1', '[-0.3757]')]
# [VectorDecomposition] [ 0.731   0.3232 -0.4026] -> [('MG3_Gen1', '[0.731]'), ('MG3_ESS1', '[0.3232]'), ('MG3_ESS2', '[-0.4026]')]
# [VectorDecomposition] [0.4501 0.2978] -> [('MG1_Gen1', '[0.4501]'), ('MG1_ESS1', '[0.2978]')]
# [VectorDecomposition] [-0.8456 -1.     -0.7217] -> [('MG2_Gen1', '[-0.8456]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.7217]')]
# [VectorDecomposition] [ 0.7591 -0.0147 -0.4884] -> [('MG3_Gen1', '[0.7591]'), ('MG3_ESS1', '[-0.0147]'), ('MG3_ESS2', '[-0.4884]')]
# [VectorDecomposition] [0.0578 0.2954] -> [('MG1_Gen1', '[0.0578]'), ('MG1_ESS1', '[0.2954]')]
# [VectorDecomposition] [-0.8354 -0.9778 -0.4944] -> [('MG2_Gen1', '[-0.8354]'), ('MG2_Gen2', '[-0.9778]'), ('MG2_ESS1', '[-0.4944]')]
# [VectorDecomposition] [ 0.3167 -0.0547 -0.3865] -> [('MG3_Gen1', '[0.3167]'), ('MG3_ESS1', '[-0.0547]'), ('MG3_ESS2', '[-0.3865]')]
#    5 |      21.01 |      18.91 |    15.58 |    -2.03 |     7.46
# [VectorDecomposition] [0.2759 0.254 ] -> [('MG1_Gen1', '[0.2759]'), ('MG1_ESS1', '[0.254]')]
# [VectorDecomposition] [-0.3318 -0.7631 -0.6144] -> [('MG2_Gen1', '[-0.3318]'), ('MG2_Gen2', '[-0.7631]'), ('MG2_ESS1', '[-0.6144]')]
# [VectorDecomposition] [ 0.3671 -0.0232 -0.1146] -> [('MG3_Gen1', '[0.3671]'), ('MG3_ESS1', '[-0.0232]'), ('MG3_ESS2', '[-0.1146]')]
# [VectorDecomposition] [0.1436 0.2854] -> [('MG1_Gen1', '[0.1436]'), ('MG1_ESS1', '[0.2854]')]
# [VectorDecomposition] [-1.     -0.8791 -0.83  ] -> [('MG2_Gen1', '[-1.]'), ('MG2_Gen2', '[-0.8791]'), ('MG2_ESS1', '[-0.83]')]
# [VectorDecomposition] [ 0.2136 -0.1438 -0.0914] -> [('MG3_Gen1', '[0.2136]'), ('MG3_ESS1', '[-0.1438]'), ('MG3_ESS2', '[-0.0914]')]
# [VectorDecomposition] [0.2938 0.6023] -> [('MG1_Gen1', '[0.2938]'), ('MG1_ESS1', '[0.6023]')]
# [VectorDecomposition] [-0.9853 -0.6896 -0.8484] -> [('MG2_Gen1', '[-0.9853]'), ('MG2_Gen2', '[-0.6896]'), ('MG2_ESS1', '[-0.8484]')]
# [VectorDecomposition] [ 0.0343 -0.0428 -0.068 ] -> [('MG3_Gen1', '[0.0343]'), ('MG3_ESS1', '[-0.0428]'), ('MG3_ESS2', '[-0.068]')]
# [VectorDecomposition] [0.2606 0.4383] -> [('MG1_Gen1', '[0.2606]'), ('MG1_ESS1', '[0.4383]')]
# [VectorDecomposition] [-0.7913 -0.8635 -0.7374] -> [('MG2_Gen1', '[-0.7913]'), ('MG2_Gen2', '[-0.8635]'), ('MG2_ESS1', '[-0.7374]')]
# [VectorDecomposition] [ 0.1567  0.1975 -0.1073] -> [('MG3_Gen1', '[0.1567]'), ('MG3_ESS1', '[0.1975]'), ('MG3_ESS2', '[-0.1073]')]
# [VectorDecomposition] [0.1163 0.3185] -> [('MG1_Gen1', '[0.1163]'), ('MG1_ESS1', '[0.3185]')]
# [VectorDecomposition] [-0.7891 -0.7676 -0.6969] -> [('MG2_Gen1', '[-0.7891]'), ('MG2_Gen2', '[-0.7676]'), ('MG2_ESS1', '[-0.6969]')]
# [VectorDecomposition] [0.4038 0.0613 0.1993] -> [('MG3_Gen1', '[0.4038]'), ('MG3_ESS1', '[0.0613]'), ('MG3_ESS2', '[0.1993]')]
# [VectorDecomposition] [0.0825 0.2601] -> [('MG1_Gen1', '[0.0825]'), ('MG1_ESS1', '[0.2601]')]
# [VectorDecomposition] [-0.784  -0.7639 -0.7029] -> [('MG2_Gen1', '[-0.784]'), ('MG2_Gen2', '[-0.7639]'), ('MG2_ESS1', '[-0.7029]')]
# [VectorDecomposition] [0.4203 0.2447 0.0234] -> [('MG3_Gen1', '[0.4203]'), ('MG3_ESS1', '[0.2447]'), ('MG3_ESS2', '[0.0234]')]
# [VectorDecomposition] [0.0804 0.3145] -> [('MG1_Gen1', '[0.0804]'), ('MG1_ESS1', '[0.3145]')]
# [VectorDecomposition] [-0.593  -0.7844 -0.9351] -> [('MG2_Gen1', '[-0.593]'), ('MG2_Gen2', '[-0.7844]'), ('MG2_ESS1', '[-0.9351]')]
# [VectorDecomposition] [0.1648 0.0016 0.0997] -> [('MG3_Gen1', '[0.1648]'), ('MG3_ESS1', '[0.0016]'), ('MG3_ESS2', '[0.0997]')]
# [VectorDecomposition] [0.1141 0.6598] -> [('MG1_Gen1', '[0.1141]'), ('MG1_ESS1', '[0.6598]')]
# [VectorDecomposition] [-0.7116 -0.8105 -0.8189] -> [('MG2_Gen1', '[-0.7116]'), ('MG2_Gen2', '[-0.8105]'), ('MG2_ESS1', '[-0.8189]')]
# [VectorDecomposition] [ 0.4229  0.0625 -0.2028] -> [('MG3_Gen1', '[0.4229]'), ('MG3_ESS1', '[0.0625]'), ('MG3_ESS2', '[-0.2028]')]
# [VectorDecomposition] [0.2105 0.3318] -> [('MG1_Gen1', '[0.2105]'), ('MG1_ESS1', '[0.3318]')]
# [VectorDecomposition] [-0.6221 -0.8277 -1.    ] -> [('MG2_Gen1', '[-0.6221]'), ('MG2_Gen2', '[-0.8277]'), ('MG2_ESS1', '[-1.]')]
# [VectorDecomposition] [ 0.3962 -0.1734  0.1462] -> [('MG3_Gen1', '[0.3962]'), ('MG3_ESS1', '[-0.1734]'), ('MG3_ESS2', '[0.1462]')]
# [VectorDecomposition] [0.3871 0.2697] -> [('MG1_Gen1', '[0.3871]'), ('MG1_ESS1', '[0.2697]')]
# [VectorDecomposition] [-0.9689 -1.     -0.6181] -> [('MG2_Gen1', '[-0.9689]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.6181]')]
# [VectorDecomposition] [ 0.3019  0.0267 -0.163 ] -> [('MG3_Gen1', '[0.3019]'), ('MG3_ESS1', '[0.0267]'), ('MG3_ESS2', '[-0.163]')]
# [VectorDecomposition] [0.4159 0.3875] -> [('MG1_Gen1', '[0.4159]'), ('MG1_ESS1', '[0.3875]')]
# [VectorDecomposition] [-0.6326 -0.6571 -0.5356] -> [('MG2_Gen1', '[-0.6326]'), ('MG2_Gen2', '[-0.6571]'), ('MG2_ESS1', '[-0.5356]')]
# [VectorDecomposition] [ 0.4917  0.0187 -0.1594] -> [('MG3_Gen1', '[0.4917]'), ('MG3_ESS1', '[0.0187]'), ('MG3_ESS2', '[-0.1594]')]
# [VectorDecomposition] [-0.0021  0.2336] -> [('MG1_Gen1', '[-0.0021]'), ('MG1_ESS1', '[0.2336]')]
# [VectorDecomposition] [-0.6583 -0.9135 -0.782 ] -> [('MG2_Gen1', '[-0.6583]'), ('MG2_Gen2', '[-0.9135]'), ('MG2_ESS1', '[-0.782]')]
# [VectorDecomposition] [ 0.234   0.0405 -0.0081] -> [('MG3_Gen1', '[0.234]'), ('MG3_ESS1', '[0.0405]'), ('MG3_ESS2', '[-0.0081]')]
# [VectorDecomposition] [0.0703 0.2567] -> [('MG1_Gen1', '[0.0703]'), ('MG1_ESS1', '[0.2567]')]
# [VectorDecomposition] [-0.7086 -0.7356 -0.6124] -> [('MG2_Gen1', '[-0.7086]'), ('MG2_Gen2', '[-0.7356]'), ('MG2_ESS1', '[-0.6124]')]
# [VectorDecomposition] [ 0.3688 -0.1291 -0.0387] -> [('MG3_Gen1', '[0.3688]'), ('MG3_ESS1', '[-0.1291]'), ('MG3_ESS2', '[-0.0387]')]
# [VectorDecomposition] [0.2033 0.4779] -> [('MG1_Gen1', '[0.2033]'), ('MG1_ESS1', '[0.4779]')]
# [VectorDecomposition] [-0.9327 -0.4571 -0.9339] -> [('MG2_Gen1', '[-0.9327]'), ('MG2_Gen2', '[-0.4571]'), ('MG2_ESS1', '[-0.9339]')]
# ...
# [VectorDecomposition] [0.2234 0.7317] -> [('MG1_Gen1', '[0.2234]'), ('MG1_ESS1', '[0.7317]')]
# [VectorDecomposition] [-1.     -0.7031 -0.8243] -> [('MG2_Gen1', '[-1.]'), ('MG2_Gen2', '[-0.7031]'), ('MG2_ESS1', '[-0.8243]')]
# [VectorDecomposition] [ 0.1132 -0.0413  0.0043] -> [('MG3_Gen1', '[0.1132]'), ('MG3_ESS1', '[-0.0413]'), ('MG3_ESS2', '[0.0043]')]
# [VectorDecomposition] [0.0388 0.6205] -> [('MG1_Gen1', '[0.0388]'), ('MG1_ESS1', '[0.6205]')]
# [VectorDecomposition] [-0.7685 -0.9237 -0.6202] -> [('MG2_Gen1', '[-0.7685]'), ('MG2_Gen2', '[-0.9237]'), ('MG2_ESS1', '[-0.6202]')]
# [VectorDecomposition] [ 0.0905 -0.1461  0.0211] -> [('MG3_Gen1', '[0.0905]'), ('MG3_ESS1', '[-0.1461]'), ('MG3_ESS2', '[0.0211]')]
# [VectorDecomposition] [0.1325 0.7653] -> [('MG1_Gen1', '[0.1325]'), ('MG1_ESS1', '[0.7653]')]
# [VectorDecomposition] [-0.7909 -0.8161 -0.6038] -> [('MG2_Gen1', '[-0.7909]'), ('MG2_Gen2', '[-0.8161]'), ('MG2_ESS1', '[-0.6038]')]
# [VectorDecomposition] [ 0.3085  0.1601 -0.2756] -> [('MG3_Gen1', '[0.3085]'), ('MG3_ESS1', '[0.1601]'), ('MG3_ESS2', '[-0.2756]')]
# [VectorDecomposition] [0.1878 0.2493] -> [('MG1_Gen1', '[0.1878]'), ('MG1_ESS1', '[0.2493]')]
# [VectorDecomposition] [-0.7742 -1.     -0.6635] -> [('MG2_Gen1', '[-0.7742]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.6635]')]
# [VectorDecomposition] [ 0.1201 -0.1777 -0.095 ] -> [('MG3_Gen1', '[0.1201]'), ('MG3_ESS1', '[-0.1777]'), ('MG3_ESS2', '[-0.095]')]
# [VectorDecomposition] [0.1515 0.5682] -> [('MG1_Gen1', '[0.1515]'), ('MG1_ESS1', '[0.5682]')]
# [VectorDecomposition] [-0.6847 -0.7557 -0.6868] -> [('MG2_Gen1', '[-0.6847]'), ('MG2_Gen2', '[-0.7557]'), ('MG2_ESS1', '[-0.6868]')]
# [VectorDecomposition] [ 0.2838  0.253  -0.4997] -> [('MG3_Gen1', '[0.2838]'), ('MG3_ESS1', '[0.253]'), ('MG3_ESS2', '[-0.4997]')]
# [VectorDecomposition] [-0.0755  0.4747] -> [('MG1_Gen1', '[-0.0755]'), ('MG1_ESS1', '[0.4747]')]
# [VectorDecomposition] [-0.7887 -0.8545 -0.571 ] -> [('MG2_Gen1', '[-0.7887]'), ('MG2_Gen2', '[-0.8545]'), ('MG2_ESS1', '[-0.571]')]
# [VectorDecomposition] [ 0.1419  0.0211 -0.3742] -> [('MG3_Gen1', '[0.1419]'), ('MG3_ESS1', '[0.0211]'), ('MG3_ESS2', '[-0.3742]')]
# [VectorDecomposition] [0.261  0.4371] -> [('MG1_Gen1', '[0.261]'), ('MG1_ESS1', '[0.4371]')]
# [VectorDecomposition] [-0.837  -0.985  -0.6395] -> [('MG2_Gen1', '[-0.837]'), ('MG2_Gen2', '[-0.985]'), ('MG2_ESS1', '[-0.6395]')]
# [VectorDecomposition] [ 0.3606 -0.2928 -0.3408] -> [('MG3_Gen1', '[0.3606]'), ('MG3_ESS1', '[-0.2928]'), ('MG3_ESS2', '[-0.3408]')]
# [VectorDecomposition] [0.0219 0.4521] -> [('MG1_Gen1', '[0.0219]'), ('MG1_ESS1', '[0.4521]')]
# [VectorDecomposition] [-0.7578 -0.6297 -0.7993] -> [('MG2_Gen1', '[-0.7578]'), ('MG2_Gen2', '[-0.6297]'), ('MG2_ESS1', '[-0.7993]')]
# [VectorDecomposition] [ 0.1281  0.2896 -0.1996] -> [('MG3_Gen1', '[0.1281]'), ('MG3_ESS1', '[0.2896]'), ('MG3_ESS2', '[-0.1996]')]
# [VectorDecomposition] [0.1334 0.4783] -> [('MG1_Gen1', '[0.1334]'), ('MG1_ESS1', '[0.4783]')]
# [VectorDecomposition] [-0.8386 -0.9666 -0.7688] -> [('MG2_Gen1', '[-0.8386]'), ('MG2_Gen2', '[-0.9666]'), ('MG2_ESS1', '[-0.7688]')]
# [VectorDecomposition] [ 0.4903  0.3419 -0.6552] -> [('MG3_Gen1', '[0.4903]'), ('MG3_ESS1', '[0.3419]'), ('MG3_ESS2', '[-0.6552]')]
# [VectorDecomposition] [0.2018 0.5923] -> [('MG1_Gen1', '[0.2018]'), ('MG1_ESS1', '[0.5923]')]
# [VectorDecomposition] [-0.6881 -0.8197 -0.7259] -> [('MG2_Gen1', '[-0.6881]'), ('MG2_Gen2', '[-0.8197]'), ('MG2_ESS1', '[-0.7259]')]
# [VectorDecomposition] [ 0.8274  0.2378 -0.6836] -> [('MG3_Gen1', '[0.8274]'), ('MG3_ESS1', '[0.2378]'), ('MG3_ESS2', '[-0.6836]')]
# [VectorDecomposition] [-0.0527  0.4692] -> [('MG1_Gen1', '[-0.0527]'), ('MG1_ESS1', '[0.4692]')]
# [VectorDecomposition] [-0.9455 -0.9227 -0.8935] -> [('MG2_Gen1', '[-0.9455]'), ('MG2_Gen2', '[-0.9227]'), ('MG2_ESS1', '[-0.8935]')]
# [VectorDecomposition] [ 0.5193  0.2241 -0.464 ] -> [('MG3_Gen1', '[0.5193]'), ('MG3_ESS1', '[0.2241]'), ('MG3_ESS2', '[-0.464]')]
# [VectorDecomposition] [0.2734 0.6299] -> [('MG1_Gen1', '[0.2734]'), ('MG1_ESS1', '[0.6299]')]
# [VectorDecomposition] [-0.7246 -0.6343 -0.7348] -> [('MG2_Gen1', '[-0.7246]'), ('MG2_Gen2', '[-0.6343]'), ('MG2_ESS1', '[-0.7348]')]
# [VectorDecomposition] [ 0.529   0.282  -0.6711] -> [('MG3_Gen1', '[0.529]'), ('MG3_ESS1', '[0.282]'), ('MG3_ESS2', '[-0.6711]')]
# [VectorDecomposition] [0.0604 0.5032] -> [('MG1_Gen1', '[0.0604]'), ('MG1_ESS1', '[0.5032]')]
# [VectorDecomposition] [-0.8321 -0.7802 -0.9906] -> [('MG2_Gen1', '[-0.8321]'), ('MG2_Gen2', '[-0.7802]'), ('MG2_ESS1', '[-0.9906]')]
# [VectorDecomposition] [ 0.5862  0.1222 -0.716 ] -> [('MG3_Gen1', '[0.5862]'), ('MG3_ESS1', '[0.1222]'), ('MG3_ESS2', '[-0.716]')]
# [VectorDecomposition] [0.2547 0.5605] -> [('MG1_Gen1', '[0.2547]'), ('MG1_ESS1', '[0.5605]')]
# [VectorDecomposition] [-0.6079 -0.8361 -0.7158] -> [('MG2_Gen1', '[-0.6079]'), ('MG2_Gen2', '[-0.8361]'), ('MG2_ESS1', '[-0.7158]')]
# [VectorDecomposition] [ 0.4694  0.1763 -0.5362] -> [('MG3_Gen1', '[0.4694]'), ('MG3_ESS1', '[0.1763]'), ('MG3_ESS2', '[-0.5362]')]
# [VectorDecomposition] [0.3267 0.5019] -> [('MG1_Gen1', '[0.3267]'), ('MG1_ESS1', '[0.5019]')]
# [VectorDecomposition] [-0.8213 -1.     -0.7897] -> [('MG2_Gen1', '[-0.8213]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.7897]')]
# [VectorDecomposition] [ 0.6355  0.1423 -0.3734] -> [('MG3_Gen1', '[0.6355]'), ('MG3_ESS1', '[0.1423]'), ('MG3_ESS2', '[-0.3734]')]
# [VectorDecomposition] [0.1207 0.7318] -> [('MG1_Gen1', '[0.1207]'), ('MG1_ESS1', '[0.7318]')]
# [VectorDecomposition] [-0.8793 -0.8847 -0.4321] -> [('MG2_Gen1', '[-0.8793]'), ('MG2_Gen2', '[-0.8847]'), ('MG2_ESS1', '[-0.4321]')]
# [VectorDecomposition] [ 0.6201  0.0673 -0.4647] -> [('MG3_Gen1', '[0.6201]'), ('MG3_ESS1', '[0.0673]'), ('MG3_ESS2', '[-0.4647]')]
# [VectorDecomposition] [0.0035 0.412 ] -> [('MG1_Gen1', '[0.0035]'), ('MG1_ESS1', '[0.412]')]
# [VectorDecomposition] [-0.7677 -0.8991 -0.9037] -> [('MG2_Gen1', '[-0.7677]'), ('MG2_Gen2', '[-0.8991]'), ('MG2_ESS1', '[-0.9037]')]
# [VectorDecomposition] [ 0.6162 -0.0016 -0.683 ] -> [('MG3_Gen1', '[0.6162]'), ('MG3_ESS1', '[-0.0016]'), ('MG3_ESS2', '[-0.683]')]
# [VectorDecomposition] [0.0253 0.5976] -> [('MG1_Gen1', '[0.0253]'), ('MG1_ESS1', '[0.5976]')]
# [VectorDecomposition] [-0.2689 -0.8922 -0.8123] -> [('MG2_Gen1', '[-0.2689]'), ('MG2_Gen2', '[-0.8922]'), ('MG2_ESS1', '[-0.8123]')]
# [VectorDecomposition] [ 0.2405  0.1475 -0.8615] -> [('MG3_Gen1', '[0.2405]'), ('MG3_ESS1', '[0.1475]'), ('MG3_ESS2', '[-0.8615]')]
# [VectorDecomposition] [0.2624 0.5981] -> [('MG1_Gen1', '[0.2624]'), ('MG1_ESS1', '[0.5981]')]
# [VectorDecomposition] [-0.9787 -0.7592 -0.8351] -> [('MG2_Gen1', '[-0.9787]'), ('MG2_Gen2', '[-0.7592]'), ('MG2_ESS1', '[-0.8351]')]
# [VectorDecomposition] [ 0.866   0.1411 -0.4854] -> [('MG3_Gen1', '[0.866]'), ('MG3_ESS1', '[0.1411]'), ('MG3_ESS2', '[-0.4854]')]
# [VectorDecomposition] [-0.1967  0.3175] -> [('MG1_Gen1', '[-0.1967]'), ('MG1_ESS1', '[0.3175]')]
# [VectorDecomposition] [-0.9796 -0.833  -0.4212] -> [('MG2_Gen1', '[-0.9796]'), ('MG2_Gen2', '[-0.833]'), ('MG2_ESS1', '[-0.4212]')]
# [VectorDecomposition] [ 0.8663  0.0338 -0.7962] -> [('MG3_Gen1', '[0.8663]'), ('MG3_ESS1', '[0.0338]'), ('MG3_ESS2', '[-0.7962]')]
# [VectorDecomposition] [0.353  0.5823] -> [('MG1_Gen1', '[0.353]'), ('MG1_ESS1', '[0.5823]')]
# [VectorDecomposition] [-0.4533 -1.     -0.555 ] -> [('MG2_Gen1', '[-0.4533]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.555]')]
# [VectorDecomposition] [-0.0661 -0.0525  0.2245] -> [('MG3_Gen1', '[-0.0661]'), ('MG3_ESS1', '[-0.0525]'), ('MG3_ESS2', '[0.2245]')]
# [VectorDecomposition] [0.2087 0.422 ] -> [('MG1_Gen1', '[0.2087]'), ('MG1_ESS1', '[0.422]')]
# [VectorDecomposition] [-0.8066 -0.9185 -0.9323] -> [('MG2_Gen1', '[-0.8066]'), ('MG2_Gen2', '[-0.9185]'), ('MG2_ESS1', '[-0.9323]')]
# [VectorDecomposition] [-0.1007 -0.0514 -0.036 ] -> [('MG3_Gen1', '[-0.1007]'), ('MG3_ESS1', '[-0.0514]'), ('MG3_ESS2', '[-0.036]')]
# [VectorDecomposition] [0.1848 0.5953] -> [('MG1_Gen1', '[0.1848]'), ('MG1_ESS1', '[0.5953]')]
# [VectorDecomposition] [-0.5085 -0.8445 -0.7628] -> [('MG2_Gen1', '[-0.5085]'), ('MG2_Gen2', '[-0.8445]'), ('MG2_ESS1', '[-0.7628]')]
# [VectorDecomposition] [ 0.0512 -0.2072  0.2794] -> [('MG3_Gen1', '[0.0512]'), ('MG3_ESS1', '[-0.2072]'), ('MG3_ESS2', '[0.2794]')]
# [VectorDecomposition] [0.1843 0.423 ] -> [('MG1_Gen1', '[0.1843]'), ('MG1_ESS1', '[0.423]')]
# [VectorDecomposition] [-0.5384 -0.8861 -0.735 ] -> [('MG2_Gen1', '[-0.5384]'), ('MG2_Gen2', '[-0.8861]'), ('MG2_ESS1', '[-0.735]')]
# [VectorDecomposition] [-0.1062  0.0813 -0.0473] -> [('MG3_Gen1', '[-0.1062]'), ('MG3_ESS1', '[0.0813]'), ('MG3_ESS2', '[-0.0473]')]
# [VectorDecomposition] [-0.0984  0.4381] -> [('MG1_Gen1', '[-0.0984]'), ('MG1_ESS1', '[0.4381]')]
# [VectorDecomposition] [-0.6964 -0.8483 -0.6858] -> [('MG2_Gen1', '[-0.6964]'), ('MG2_Gen2', '[-0.8483]'), ('MG2_ESS1', '[-0.6858]')]
# [VectorDecomposition] [-0.0484 -0.1802 -0.009 ] -> [('MG3_Gen1', '[-0.0484]'), ('MG3_ESS1', '[-0.1802]'), ('MG3_ESS2', '[-0.009]')]
# [VectorDecomposition] [0.2737 0.3029] -> [('MG1_Gen1', '[0.2737]'), ('MG1_ESS1', '[0.3029]')]
# [VectorDecomposition] [-0.622  -0.9993 -0.7848] -> [('MG2_Gen1', '[-0.622]'), ('MG2_Gen2', '[-0.9993]'), ('MG2_ESS1', '[-0.7848]')]
# [VectorDecomposition] [-0.0399 -0.2355  0.2268] -> [('MG3_Gen1', '[-0.0399]'), ('MG3_ESS1', '[-0.2355]'), ('MG3_ESS2', '[0.2268]')]
# [VectorDecomposition] [-0.1997  0.5516] -> [('MG1_Gen1', '[-0.1997]'), ('MG1_ESS1', '[0.5516]')]
# [VectorDecomposition] [-0.8317 -0.9727 -1.    ] -> [('MG2_Gen1', '[-0.8317]'), ('MG2_Gen2', '[-0.9727]'), ('MG2_ESS1', '[-1.]')]
# [VectorDecomposition] [ 0.2342  0.0925 -0.1596] -> [('MG3_Gen1', '[0.2342]'), ('MG3_ESS1', '[0.0925]'), ('MG3_ESS2', '[-0.1596]')]
# [VectorDecomposition] [0.0133 0.46  ] -> [('MG1_Gen1', '[0.0133]'), ('MG1_ESS1', '[0.46]')]
# [VectorDecomposition] [-0.4387 -1.     -0.7807] -> [('MG2_Gen1', '[-0.4387]'), ('MG2_Gen2', '[-1.]'), ('MG2_ESS1', '[-0.7807]')]
# [VectorDecomposition] [ 0.3986  0.0005 -0.1525] -> [('MG3_Gen1', '[0.3986]'), ('MG3_ESS1', '[0.0005]'), ('MG3_ESS2', '[-0.1525]')]
# [VectorDecomposition] [0.2045 0.5253] -> [('MG1_Gen1', '[0.2045]'), ('MG1_ESS1', '[0.5253]')]
# [VectorDecomposition] [-0.9254 -0.8765 -0.6983] -> [('MG2_Gen1', '[-0.9254]'), ('MG2_Gen2', '[-0.8765]'), ('MG2_ESS1', '[-0.6983]')]
# [VectorDecomposition] [ 0.3573 -0.1433 -0.332 ] -> [('MG3_Gen1', '[0.3573]'), ('MG3_ESS1', '[-0.1433]'), ('MG3_ESS2', '[-0.332]')]
# [VectorDecomposition] [-0.0237  0.6597] -> [('MG1_Gen1', '[-0.0237]'), ('MG1_ESS1', '[0.6597]')]
# [VectorDecomposition] [-0.7515 -0.8982 -0.6848] -> [('MG2_Gen1', '[-0.7515]'), ('MG2_Gen2', '[-0.8982]'), ('MG2_ESS1', '[-0.6848]')]
# [VectorDecomposition] [ 0.5244  0.2451 -0.2793] -> [('MG3_Gen1', '[0.5244]'), ('MG3_ESS1', '[0.2451]'), ('MG3_ESS2', '[-0.2793]')]
# [VectorDecomposition] [-0.271   0.5551] -> [('MG1_Gen1', '[-0.271]'), ('MG1_ESS1', '[0.5551]')]
# [VectorDecomposition] [-0.7939 -0.7178 -0.8063] -> [('MG2_Gen1', '[-0.7939]'), ('MG2_Gen2', '[-0.7178]'), ('MG2_ESS1', '[-0.8063]')]
# [VectorDecomposition] [ 0.2159  0.0882 -0.5324] -> [('MG3_Gen1', '[0.2159]'), ('MG3_ESS1', '[0.0882]'), ('MG3_ESS2', '[-0.5324]')]
# [VectorDecomposition] [0.2661 0.6102] -> [('MG1_Gen1', '[0.2661]'), ('MG1_ESS1', '[0.6102]')]
# [VectorDecomposition] [-0.6489 -0.7145 -0.5187] -> [('MG2_Gen1', '[-0.6489]'), ('MG2_Gen2', '[-0.7145]'), ('MG2_ESS1', '[-0.5187]')]
# [VectorDecomposition] [ 0.3763  0.0576 -0.7202] -> [('MG3_Gen1', '[0.3763]'), ('MG3_ESS1', '[0.0576]'), ('MG3_ESS2', '[-0.7202]')]
# [VectorDecomposition] [0.0499 0.5675] -> [('MG1_Gen1', '[0.0499]'), ('MG1_ESS1', '[0.5675]')]
# [VectorDecomposition] [-0.6037 -0.8201 -0.5314] -> [('MG2_Gen1', '[-0.6037]'), ('MG2_Gen2', '[-0.8201]'), ('MG2_ESS1', '[-0.5314]')]
# [VectorDecomposition] [ 0.3112 -0.1279 -0.3554] -> [('MG3_Gen1', '[0.3112]'), ('MG3_ESS1', '[-0.1279]'), ('MG3_ESS2', '[-0.3554]')]
# [VectorDecomposition] [0.1112 0.5201] -> [('MG1_Gen1', '[0.1112]'), ('MG1_ESS1', '[0.5201]')]
# [VectorDecomposition] [-0.5265 -0.9197 -0.7261] -> [('MG2_Gen1', '[-0.5265]'), ('MG2_Gen2', '[-0.9197]'), ('MG2_ESS1', '[-0.7261]')]
# [VectorDecomposition] [ 0.6073  0.     -0.6176] -> [('MG3_Gen1', '[0.6073]'), ('MG3_ESS1', '[0.]'), ('MG3_ESS2', '[-0.6176]')]
# [VectorDecomposition] [0.1864 0.4444] -> [('MG1_Gen1', '[0.1864]'), ('MG1_ESS1', '[0.4444]')]
# [VectorDecomposition] [-0.5732 -0.752  -0.6042] -> [('MG2_Gen1', '[-0.5732]'), ('MG2_Gen2', '[-0.752]'), ('MG2_ESS1', '[-0.6042]')]
# [VectorDecomposition] [ 0.601   0.1308 -0.5002] -> [('MG3_Gen1', '[0.601]'), ('MG3_ESS1', '[0.1308]'), ('MG3_ESS2', '[-0.5002]')]
# [VectorDecomposition] [0.1514 0.5616] -> [('MG1_Gen1', '[0.1514]'), ('MG1_ESS1', '[0.5616]')]
# [VectorDecomposition] [-0.9181 -0.8239 -0.8872] -> [('MG2_Gen1', '[-0.9181]'), ('MG2_Gen2', '[-0.8239]'), ('MG2_ESS1', '[-0.8872]')]
# [VectorDecomposition] [ 0.6399  0.0322 -0.3743] -> [('MG3_Gen1', '[0.6399]'), ('MG3_ESS1', '[0.0322]'), ('MG3_ESS2', '[-0.3743]')]
# [VectorDecomposition] [0.1305 0.4955] -> [('MG1_Gen1', '[0.1305]'), ('MG1_ESS1', '[0.4955]')]
# [VectorDecomposition] [-0.7791 -0.7867 -0.8697] -> [('MG2_Gen1', '[-0.7791]'), ('MG2_Gen2', '[-0.7867]'), ('MG2_ESS1', '[-0.8697]')]
# [VectorDecomposition] [ 0.5451  0.172  -0.5379] -> [('MG3_Gen1', '[0.5451]'), ('MG3_ESS1', '[0.172]'), ('MG3_ESS2', '[-0.5379]')]
# [VectorDecomposition] [0.1984 0.6157] -> [('MG1_Gen1', '[0.1984]'), ('MG1_ESS1', '[0.6157]')]
# [VectorDecomposition] [-0.954  -0.9432 -0.9358] -> [('MG2_Gen1', '[-0.954]'), ('MG2_Gen2', '[-0.9432]'), ('MG2_ESS1', '[-0.9358]')]
# [VectorDecomposition] [ 0.4199  0.0455 -0.5371] -> [('MG3_Gen1', '[0.4199]'), ('MG3_ESS1', '[0.0455]'), ('MG3_ESS2', '[-0.5371]')]
# [VectorDecomposition] [0.0624 0.4374] -> [('MG1_Gen1', '[0.0624]'), ('MG1_ESS1', '[0.4374]')]
# [VectorDecomposition] [-0.7628 -0.918  -0.7039] -> [('MG2_Gen1', '[-0.7628]'), ('MG2_Gen2', '[-0.918]'), ('MG2_ESS1', '[-0.7039]')]
# [VectorDecomposition] [ 0.5092  0.2102 -0.725 ] -> [('MG3_Gen1', '[0.5092]'), ('MG3_ESS1', '[0.2102]'), ('MG3_ESS2', '[-0.725]')]
# [VectorDecomposition] [0.2007 0.5308] -> [('MG1_Gen1', '[0.2007]'), ('MG1_ESS1', '[0.5308]')]
# [VectorDecomposition] [-0.7659 -0.6695 -0.7449] -> [('MG2_Gen1', '[-0.7659]'), ('MG2_Gen2', '[-0.6695]'), ('MG2_ESS1', '[-0.7449]')]
# [VectorDecomposition] [ 0.4318 -0.215  -0.6025] -> [('MG3_Gen1', '[0.4318]'), ('MG3_ESS1', '[-0.215]'), ('MG3_ESS2', '[-0.6025]')]
# [VectorDecomposition] [0.2363 0.4578] -> [('MG1_Gen1', '[0.2363]'), ('MG1_ESS1', '[0.4578]')]
# [VectorDecomposition] [-0.933  -0.8823 -0.784 ] -> [('MG2_Gen1', '[-0.933]'), ('MG2_Gen2', '[-0.8823]'), ('MG2_ESS1', '[-0.784]')]
# [VectorDecomposition] [ 0.6541  0.2444 -0.4034] -> [('MG3_Gen1', '[0.6541]'), ('MG3_ESS1', '[0.2444]'), ('MG3_ESS2', '[-0.4034]')]
# [VectorDecomposition] [0.1381 0.5026] -> [('MG1_Gen1', '[0.1381]'), ('MG1_ESS1', '[0.5026]')]
# [VectorDecomposition] [-0.7553 -0.8638 -0.6677] -> [('MG2_Gen1', '[-0.7553]'), ('MG2_Gen2', '[-0.8638]'), ('MG2_ESS1', '[-0.6677]')]
# [VectorDecomposition] [ 0.5039  0.219  -0.6487] -> [('MG3_Gen1', '[0.5039]'), ('MG3_ESS1', '[0.219]'), ('MG3_ESS2', '[-0.6487]')]
# [VectorDecomposition] [0.1565 0.7257] -> [('MG1_Gen1', '[0.1565]'), ('MG1_ESS1', '[0.7257]')]
# [VectorDecomposition] [-0.8184 -0.7398 -0.7015] -> [('MG2_Gen1', '[-0.8184]'), ('MG2_Gen2', '[-0.7398]'), ('MG2_ESS1', '[-0.7015]')]
# [VectorDecomposition] [ 0.6193 -0.049  -0.7322] -> [('MG3_Gen1', '[0.6193]'), ('MG3_ESS1', '[-0.049]'), ('MG3_ESS2', '[-0.7322]')]
# [VectorDecomposition] [0.2348 0.3147] -> [('MG1_Gen1', '[0.2348]'), ('MG1_ESS1', '[0.3147]')]
# [VectorDecomposition] [-0.8837 -0.834  -0.8328] -> [('MG2_Gen1', '[-0.8837]'), ('MG2_Gen2', '[-0.834]'), ('MG2_ESS1', '[-0.8328]')]
# [VectorDecomposition] [ 0.6997  0.1396 -0.6671] -> [('MG3_Gen1', '[0.6997]'), ('MG3_ESS1', '[0.1396]'), ('MG3_ESS2', '[-0.6671]')]
#   30 |      28.01 |      27.33 |    15.70 |    -2.18 |    14.49
# ============================================================
# Training complete!
#   Initial return (first 5): 18.91
#   Final return (last 5):    27.33

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Episode returns
axes[0].plot(returns_history, 'b-', alpha=0.3, label='Episode')
window = 5
if len(returns_history) >= window:
    ma = [np.mean(returns_history[max(0,i-window+1):i+1]) for i in range(len(returns_history))]
    axes[0].plot(ma, 'b-', linewidth=2, label=f'MA({window})')
axes[0].set_xlabel('Episode')
axes[0].set_ylabel('Return')
axes[0].set_title('CTDE Training Progress')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Per-microgrid rewards
colors = ['tab:blue', 'tab:orange', 'tab:green']
for i, (cid, rewards) in enumerate(mg_rewards_history.items()):
    axes[1].plot(rewards, color=colors[i % len(colors)], alpha=0.5, label=cid)
axes[1].set_xlabel('Episode')
axes[1].set_ylabel('Episode Reward')
axes[1].set_title('Per-Microgrid Rewards')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 5: Event-Driven Evaluation
#
# After training in synchronous mode, we evaluate with event-driven execution.
# This tests policy robustness under realistic timing (jitter, delays, heterogeneous tick rates).

# %%
# Attach trained policies to coordinators
for coord_id, policy in coordinator_policies.items():
    agent = env.registered_agents.get(coord_id)
    if agent is not None:
        agent.policy = policy

# Configure realistic timing for event-driven execution
system_schedule_config = ScheduleConfig.with_jitter(
    tick_interval=30.0, obs_delay=0.3, act_delay=0.5, msg_delay=0.2,
    jitter_type=JitterType.GAUSSIAN, jitter_ratio=0.1, seed=41,
)
coordinator_schedule_config = ScheduleConfig.with_jitter(
    tick_interval=10.0, obs_delay=0.2, act_delay=0.3, msg_delay=0.15,
    jitter_type=JitterType.GAUSSIAN, jitter_ratio=0.1, seed=43,
)
field_schedule_config = ScheduleConfig.with_jitter(
    tick_interval=5.0, obs_delay=0.1, act_delay=0.2, msg_delay=0.1,
    jitter_type=JitterType.GAUSSIAN, jitter_ratio=0.1, seed=42,
)

# Apply tick configs to agents
for agent_id, agent in env.registered_agents.items():
    if agent_id == "system_agent":
        agent.schedule_config = system_schedule_config
    elif isinstance(agent, PowerGridAgent):
        agent.schedule_config = coordinator_schedule_config
        for sub_agent in agent.subordinates.values():
            sub_agent.schedule_config = field_schedule_config
    elif hasattr(agent, 'schedule_config') and agent_id != "proxy_agent":
        agent.schedule_config = field_schedule_config

# Update scheduler's cached tick configs
for agent_id, agent in env.registered_agents.items():
    if hasattr(agent, 'schedule_config'):
        env.scheduler._agent_schedule_configs[agent_id] = agent.schedule_config

# Reset and run event-driven
env.reset(seed=100)
episode_analyzer = EpisodeAnalyzer(verbose=False)

print("Running event-driven evaluation (t_end=300.0)...")
result = env.run_event_driven(episode_analyzer=episode_analyzer, t_end=300.0)

print(f"\nResults:")
print(f"  Events processed: {result.num_events}")
print(f"  Duration: {result.duration:.1f}s")
print(f"  Observations: {episode_analyzer.observation_count}")
print(f"  State updates: {episode_analyzer.state_update_count}")
print(f"  Action results: {episode_analyzer.action_result_count}")

# Event type breakdown
event_counts = result.get_event_counts()
print(f"\nEvent breakdown:")
for etype, count in event_counts.items():
    print(f"  {etype.value}: {count}")
# Out:
# Running event-driven evaluation (t_end=300.0)...
# SystemAgent(id=system_agent, coordinators=3, protocol=None) doesn't act iself, becase there's no action policy
# using proxy agent message delivery handler
# [VectorDecomposition] [-0.2398  0.0934  0.2026] -> [('MG3_Gen1', '[-0.2398]'), ('MG3_ESS1', '[0.0934]'), ('MG3_ESS2', '[0.2026]')]
# using proxy agent message delivery handler
# [VectorDecomposition] [0.0761 0.3496] -> [('MG1_Gen1', '[0.0761]'), ('MG1_ESS1', '[0.3496]')]
# using proxy agent message delivery handler
# [VectorDecomposition] [-0.5727 -0.6432 -0.7023] -> [('MG2_Gen1', '[-0.5727]'), ('MG2_Gen2', '[-0.6432]'), ('MG2_ESS1', '[-0.7023]')]
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# Received tick result from MG3_ESS1: {'reward': 0.8190407354850322, 'terminated': False, 'truncated': False, 'info': {}}
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# Received tick result from MG1_ESS1: {'reward': 0.8999999750158948, 'terminated': False, 'truncated': False, 'info': {}}
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# Received tick result from MG3_Gen1: {'reward': -0.17879793047904968, 'terminated': False, 'truncated': False, 'info': {}}
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# Received tick result from MG3_ESS2: {'reward': 0.12694764230400324, 'terminated': False, 'truncated': False, 'info': {}}
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# Received tick result from MG2_Gen1: {'reward': -0.11777305603027344, 'terminated': False, 'truncated': False, 'info': {}}
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# Received tick result from MG2_ESS1: {'reward': 0.10000000145511194, 'terminated': False, 'truncated': False, 'info': {}}
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# using proxy agent message delivery handler
# Received tick result from MG1_Gen1: {'reward': -0.23711645603179932, 'terminated': False, 'truncated': False, 'info': {}}
# using proxy agent message delivery handler
# Received tick result from MG2_Gen2: {'reward': -0.17672698199748993, 'terminated': False, 'truncated': False, 'info': {}}
#
# Results:
#   Events processed: 70
#   Duration: 300.0s
#   Observations: 3
#   State updates: 8
#   Action results: 8
#
# Event breakdown:
#   agent_tick: 12
#   message_delivery: 46
#   action_effect: 11
#   simulation: 1

# %% [markdown]
# ## Key Takeaways
#
# ### CTDE Architecture
#
# | Component | Role |
# |-----------|------|
# | **Coordinator (L2)** | Owns the RL policy, computes joint actions |
# | **VerticalProtocol** | Decomposes joint action into per-device actions |
# | **Devices (L1)** | Apply individual actions, report rewards |
# | **SystemAgent (L3)** | Orchestrates the step/tick cycle |
#
# ### Training Flow
#
# ```python
# # 1. Coordinator aggregates device observations
# agg_obs = concat([obs[device_id] for device_id in coordinator.subordinates])
#
# # 2. Policy computes joint action
# joint_action = policy.forward(agg_obs)  # Uses @obs_to_vector, @vector_to_action
#
# # 3. Protocol distributes to devices
# device_actions = protocol.coordinate(coordinator_state, joint_action, ...)
#
# # 4. Environment steps all devices
# obs, rewards, ... = env.step(device_actions)
#
# # 5. Coordinator aggregates device rewards
# coord_reward = sum(rewards[device_id] for device_id in coordinator.subordinates)
# ```
#
# ### Dual Execution Modes
#
# - **Synchronous** (`env.step()`): Fast training, all agents step together
# - **Event-driven** (`env.run_event_driven()`): Realistic testing with jitter and delays
#
# ---
#
# **Next:** [05_event_driven_testing.ipynb](05_event_driven_testing.ipynb) — Deep dive into event-driven testing with timing analysis
